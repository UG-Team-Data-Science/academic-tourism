# %%
from openai import OpenAI

import os

base_url = "https://llm.hpc.rug.nl/"
model_name = "mistralai/Mistral-Small-3.2-24B-Instruct-2506"

api_key = os.getenv("RUGLLM_API_KEY")

client = OpenAI(base_url=base_url, api_key=api_key)

# %%
# test UG LLM compatibilty with response_format

from pydantic import BaseModel

class CalendarEvent(BaseModel):
    name: str
    date: str
    participants: list[str]


completion = client.beta.chat.completions.parse(
    model=model_name,
    messages=[
        {"role": "system", "content": "Extract the event information."},
        {
            "role": "user",
            "content": "Alice and Bob are going to a science fair on Friday.",
        },
    ],
    response_format=CalendarEvent,
)

completion.choices[0].message.parsed
# Out:
# CalendarEvent(name='science fair', date='Friday', participants=['Alice', 'Bob'])

# %% [markdown]
# 👍 in UG llm logs:
#
# ```
#  mistral_small 	INFO 08-29 02:31:51 [logger.py:43] Received request chatcmpl-7ed491e616e948f6a011cd3438bfacf6: prompt: None, params: SamplingParams(n=1, presence_penalty=0.0, frequency_penalty=0.0, repetition_penalty=1.0, temperature=0.7, top_p=0.95, top_k=0, min_p=0.0, seed=None, stop=[], stop_token_ids=[], bad_words=[], include_stop_str_in_output=False, ignore_eos=False, max_tokens=131050, min_tokens=0, logprobs=None, prompt_logprobs=None, skip_special_tokens=True, spaces_between_special_tokens=True, truncate_prompt_tokens=None, guided_decoding=GuidedDecodingParams(json={'properties': {'name': {'title': 'Name', 'type': 'string'}, 'date': {'title': 'Date', 'type': 'string'}, 'participants': {'items': {'type': 'string'}, 'title': 'Participants', 'type': 'array'}}, 'required': ['name', 'date', 'participants'], 'title': 'CalendarEvent', 'type': 'object', 'additionalProperties': False}, regex=None, choice=None, grammar=None, json_object=None, backend=None, backend_was_auto=False, disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, whitespace_pattern=None, structural_tag=None), extra_args=None), prompt_token_ids: [1, 17, 91108, 1278, 3349, 3686, 1046, 18, 3, 66899, 1321, 12382, 1584, 4670, 1317, 1261, 12470, 13177, 1408, 27533, 1046, 4], prompt_embeds shape: None, lora_request: None, prompt_adapter_request: None.
# ```

# %%
import pandas as pd

df_annotations = pd.read_json("data/examples_from_annotations.jsonl", lines=True)

# %%
df_annotations.head()
# Out:
#                                                 text  \
# 0                                       Zesde Brief.
# 1  Op de Bloksberg  des morgens van den 15 July 1...
# 2                                   Waardste Vriend!
# 3  U te melden wat wy deeze dagen op onze reis do...
# 4  Hoe zoude ik toch schriftelyk kunnen vermelden...
#
#                                               labels  \
# 0                                                 []
# 1  [{'span': 'Bloksberg', 'types': ['E53 Place', ...
# 2                                                 []
# 3         [{'span': 'Harz', 'types': ['E53 Place']}]
# 4  [{'span': 'eenige honderd voet diep', 'types':...
#
#                               source
# 0  Zesde Brief (met annotaties).docx
# 1  Zesde Brief (met annotaties).docx
# 2  Zesde Brief (met annotaties).docx
# 3  Zesde Brief (met annotaties).docx
# 4  Zesde Brief (met annotaties).docx

# %%
# example adapted from intfloat/multilingual-e5-base readme

import torch.nn.functional as F
import torch
from torch import Tensor
from transformers import AutoTokenizer, AutoModel
from typing import List


def average_pool(last_hidden_states: Tensor, attention_mask: Tensor) -> Tensor:
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]


def get_embeddings_batched(texts: List[str], model, tokenizer, batch_size=8):
    """Process texts in batches and return embeddings."""
    all_embeddings = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i : i + batch_size]

        # Tokenize the batch
        batch_dict = tokenizer(
            batch_texts,
            max_length=512,
            padding=True,
            truncation=True,
            return_tensors="pt",
        )

        # Get embeddings for the batch
        with torch.no_grad():  # Disable gradient calculation for inference
            outputs = model(**batch_dict)
            batch_embeddings = average_pool(
                outputs.last_hidden_state, batch_dict["attention_mask"]
            )
            batch_embeddings = F.normalize(batch_embeddings, p=2, dim=1)

        all_embeddings.append(batch_embeddings)

    # Concatenate all batch embeddings
    return torch.cat(all_embeddings, dim=0)


# Each input text should start with "query: " or "passage: ", even for non-English texts.
input_texts = [
    "query: how much protein should a female eat",
    "query: 南瓜的家常做法",
    "passage: As a general guideline, the CDC's average requirement of protein for women ages 19 to 70 is 46 grams per day. But, as you can see from this chart, you'll need to increase that if you're expecting or training for a marathon. Check out the chart below to see how much protein you should be eating each day.",
    "passage: 1.清炒南瓜丝 原料:嫩南瓜半个 调料:葱、盐、白糖、鸡精 做法: 1、南瓜用刀薄薄的削去表面一层皮,用勺子刮去瓤 2、擦成细丝(没有擦菜板就用刀慢慢切成细丝) 3、锅烧热放油,入葱花煸出香味 4、入南瓜丝快速翻炒一分钟左右,放盐、一点白糖和鸡精调味出锅 2.香葱炒南瓜 原料:南瓜1只 调料:香葱、蒜末、橄榄油、盐 做法: 1、将南瓜去皮,切成片 2、油锅8成热后,将蒜末放入爆香 3、爆香后,将南瓜片放入,翻炒 4、在翻炒的同时,可以不时地往锅里加水,但不要太多 5、放入盐,炒匀 6、南瓜差不多软和绵了之后,就可以关火 7、撒入香葱,即可出锅",
]

tokenizer = AutoTokenizer.from_pretrained("intfloat/multilingual-e5-base")
model = AutoModel.from_pretrained("intfloat/multilingual-e5-base")

# Split into queries and passages
queries = [text for text in input_texts if text.startswith("query:")]
passages = [text for text in input_texts if text.startswith("passage:")]

# Get embeddings in batches
batch_size = 8  # Adjust based on your memory constraints
query_embeddings = get_embeddings_batched(queries, model, tokenizer, batch_size)
passage_embeddings = get_embeddings_batched(passages, model, tokenizer, batch_size)

# Calculate similarity scores
scores = (query_embeddings @ passage_embeddings.T) * 100
print(scores.tolist())
# Out:
# [[90.79100799560547, 71.17613220214844], [72.53498077392578, 90.14604949951172]]

# %%
from pathlib import Path
import json

datadir = Path("data")
all_examples_file = datadir.joinpath("examples_cleaned.jsonl")

with all_examples_file.open("r", encoding="utf-8") as f:
    all_examples = [json.loads(line) for line in f]

sentences_to_embed = [f"query: {ex['text']}" for ex in all_examples]

embeddings = get_embeddings_batched(sentences_to_embed, model, tokenizer, batch_size)

# %%
for ex, emb in zip(all_examples, embeddings.numpy()):
    ex["text_embedding"] = emb

df = pd.DataFrame(all_examples)
test_file = "Ontology-based Annotation.docx"
train_file = "Zesde Brief (met annotaties).docx"
df_test = df.query(f"source == '{test_file}'")
df_train = df.query(f"source == '{train_file}'")

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

embeddings_train = np.stack(df_train["text_embedding"])
embeddings_test = np.stack(df_test["text_embedding"])


n_fewshot_examples = 5
nn = NearestNeighbors(n_neighbors=n_fewshot_examples, metric="cosine").fit(embeddings_train)

distances, indices = nn.kneighbors(embeddings_test)

# %%
test_index = 3
print("Test example:")
print(df_test.iloc[test_index])
print("Most similar train examples::")
print(df_train.iloc[indices[test_index]])
# Out:
# Test example:
# text              Wilhelmshöhe, voorheen Weissenstein genoemd en...
# labels            [{'span': 'Wilhelmshöhe', 'types': ['E53 Place...
# source                               Ontology-based Annotation.docx
# text_embedding    [0.014872815, 0.052165806, -0.04137797, 0.0222...
# Name: 110, dtype: object
# Most similar train examples::
#                                                  text  \
# 21  Hiermede gingen wy   [43] die naar het naburig...
# 57  Hier hielden wy ons weder een oogenblik op en ...
# 75  Nu hadden wy echter het schoone van de weg op ...
# 98  Gegend von Wernigerode von den 12 Morgen gesehen]
# 48  De verandering van temperatuur was hier aanmer...
#
#                                                labels  \
# 21  [{'span': 'gingen wy', 'types': ['E9 Move']}, ...
# 57  [{'span': 'geruime tyd', 'types': ['E54 Dimens...
# 75  [{'span': '3 uur', 'types': ['E52 Time-Span']}...
# 98                                                 []
# 48  [{'span': 'hoogte van 293 toises of 1758 Parys...
#
#                                source  \
# 21  Zesde Brief (met annotaties).docx
# 57  Zesde Brief (met annotaties).docx
# 75  Zesde Brief (met annotaties).docx
# 98  Zesde Brief (met annotaties).docx
# 48  Zesde Brief (met annotaties).docx
#
#                                        text_embedding
# 21  [0.027846185, 0.036472447, -0.0036003236, 0.01...
# 57  [0.0011036679, 0.031524315, -0.02372831, -0.00...
# 75  [0.035734136, 0.046055514, -0.017662942, 0.023...
# 98  [-6.334169e-05, 0.026554504, -0.019620417, 0.0...
# 48  [-0.018094052, 0.024273423, -0.015384173, -0.0...

# %%
unique_labels = (
    df_train["labels"]
    .explode()
    .dropna()
    .apply(lambda x: x["types"])
    .explode()
    .value_counts()
    .index.to_list()
)

# %%
system_prompt_template = f"""
You are an expert annotator of old Dutch texts. You always return annotations as valid JSON.

You output the following labels: {', '.join(unique_labels)}

A single span can be assigned multiple labels.

Here are a few examples:
{{}}
""".strip()

# %%
type(df_train["labels"].iloc[1][0])
# Out:
# dict

# %%
unique_labels
# Out:
# ['E53 Place',
#  'E19 Physical Thing',
#  'E21 Person',
#  'E52 Time-Span',
#  'E54 Dimension',
#  'E86 Leaving',
#  'E74 Group',
#  'E9 Move']

# %%
def format_examples(examples: pd.DataFrame):
    return "\n\n".join(
        [
            f"Sentence:\n{ex['text']}\nAnnotation:\n{json.dumps({'entities': ex['labels']}, ensure_ascii=False)}"
            for ex in examples.to_records()
        ]
    )


print(format_examples(df_train.iloc[indices[test_index]]))
# Out:
# Sentence:
# Hiermede gingen wy   [43] die naar het naburig Zellerfeld  was gewandelt) onder geleide van een gids naar de voornaamste ingang der mynen ongeveer ¾ uur  van de stad gelegen:
# Annotation:
# {"entities": [{"span": "gingen wy", "types": ["E9 Move"]}, {"span": "Zellerfeld", "types": ["E53 Place"]}, {"span": "¾ uur", "types": ["E54 Dimension"]}]}
#
# Sentence:
# Hier hielden wy ons weder een oogenblik op en bestegen toen weder den berg alwaar wy op een smal pad een geruime tyd  moesten wagten wyl ons hier eene menigte ezels tegenkwamen met lange zakken op den rug die juist de breedte van de weg besloegen zoodat wy niet passeren konden: hier ruischte een helder beekje waarvan het yskoude water heerlyk smaakte: na nog anderhalf uur  gewandelt te hebben kregen wy de stad Andreasberg  in het oog, dezelve is nog hoger als Clausthal  en wel 1817 voet  boven de Oostzee verheven, weldra waren wy in dezelve & het schoone logement binnen getreden.
# Annotation:
# {"entities": [{"span": "geruime tyd", "types": ["E54 Dimension"]}, {"span": "anderhalf uur", "types": ["E54 Dimension"]}, {"span": "Andreasberg", "types": ["E53 Place"]}, {"span": "Clausthal", "types": ["E53 Place"]}, {"span": "1817 voet", "types": ["E54 Dimension"]}]}
#
# Sentence:
# Nu hadden wy echter het schoone van de weg op en moesten over een portie steenen al hortende en botsende ryden tot wy ongeveer 3 uur  te Oderbrücke aankwamen:
# Annotation:
# {"entities": [{"span": "3 uur", "types": ["E52 Time-Span"]}, {"span": "Oderbrücke", "types": ["E53 Place"]}]}
#
# Sentence:
# Gegend von Wernigerode von den 12 Morgen gesehen]
# Annotation:
# {"entities": []}
#
# Sentence:
# De verandering van temperatuur was hier aanmerkelyk ook is de stad volgens de waarnemingen van Villefosse op de hoogte van 293 toises of 1758 Parysche voeten  boven de oppervlakte der Oostzee gelegen: in byna elken kamer zelfs in het armmoedigste huttje wierd een grootte kacchel gestookt hetgeen men ons zeide dat gedurende de gansche zomer plaats had, dit kwam ons vreemd over doch was ons met dat al zeer welkom.
# Annotation:
# {"entities": [{"span": "hoogte van 293 toises of 1758 Parysche voeten", "types": ["E54 Dimension"]}]}

# %%
from typing import List, Literal
from pydantic import BaseModel

# Define the allowed entity types using Literal for type validation
EntityType = Literal[
    'E53 Place',
    'E19 Physical Thing',
    'E21 Person',
    'E52 Time-Span',
    'E54 Dimension',
    'E86 Leaving',
    'E74 Group',
    'E9 Move'
]

class Entity(BaseModel):
    span: str
    types: List[EntityType]

class EntityOutput(BaseModel):
    entities: List[Entity]

# %%
from tqdm import trange

responses = []

for idx in trange(len(df_test)):

    system_prompt = system_prompt_template.format(
        format_examples(df_train.iloc[indices[idx]])
    )

    completion = client.beta.chat.completions.parse(
        model=model_name,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": df_test.iloc[idx]["text"]},
        ],
        temperature=0.15,
        response_format=EntityOutput,
    )

    responses.append(completion.choices[0].message.parsed)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 223/223 [08:49<00:00,  2.38s/it]

# %%
responses
# Out:
# [EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='9 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Wilhelmshöhe', types=['E53 Place']), Entity(span='Weissenstein', types=['E53 Place']), Entity(span='Napoleonshöhe', types=['E53 Place']), Entity(span='Keurvorst van Hessen Cassel', types=['E74 Group']), Entity(span='groot uur', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='landgraven Karel', types=['E74 Group']), Entity(span='Frederik de II', types=['E21 Person']), Entity(span='Keurvorst Willem de IX', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Zondag ll', types=['E52 Time-Span']), Entity(span='Weissenstein', types=['E53 Place']), Entity(span='groote gewoel der wandelaars zoo wel inwoners der stad als vreemdelingen', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Casernes', types=['E19 Physical Thing']), Entity(span='30,000 man', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Wilhelmshöhe', types=['E53 Place']), Entity(span='Gulielmus IX', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='62 voeten doorsnede', types=['E54 Dimension']), Entity(span='Cassel', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='7 voet breed en 9½ voet hoog', types=['E54 Dimension']), Entity(span='Z Hoogheid', types=['E21 Person']), Entity(span='Hieronymus', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='bibliotheek', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='6 Groninger Menoniten', types=['E74 Group']), Entity(span='daags na ons vertrokken', types=['E86 Leaving']), Entity(span='vorige dag', types=['E52 Time-Span']), Entity(span='Cassel', types=['E53 Place']), Entity(span='Hr van Assen', types=['E21 Person']), Entity(span='Z.H. Prins Frederik', types=['E21 Person']), Entity(span='Student Hogendorp', types=['E21 Person']), Entity(span='insgelyks in Cassel gearriveerd', types=['E9 Move']), Entity(span='Hr de Geer', types=['E21 Person']), Entity(span='Francfort', types=['E53 Place']), Entity(span='1 Augustus', types=['E52 Time-Span']), Entity(span='den Haag', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='gezelschap', types=['E74 Group']), Entity(span='bibliotheek', types=['E19 Physical Thing']), Entity(span='vertrek', types=['E19 Physical Thing']), Entity(span='dubbele deuren', types=['E19 Physical Thing']), Entity(span='Heer Hogendorp', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='eenige tyd', types=['E52 Time-Span']), Entity(span='vengster', types=['E19 Physical Thing']), Entity(span='het hoofdgebouw', types=['E19 Physical Thing']), Entity(span='der vleugels', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Titschbein', types=['E21 Person']), Entity(span='Gierusalemne liberata', types=['E19 Physical Thing']), Entity(span='Torquato Tasso', types=['E21 Person']), Entity(span='Wieland’s Oberon', types=['E19 Physical Thing']), Entity(span='beschreibung des Kurfürstlichen Landsitzes Wilhelmshöhe bey Cassel', types=['E19 Physical Thing']), Entity(span='1804', types=['E52 Time-Span']), Entity(span='W. Döring', types=['E21 Person']), Entity(span='Cassel', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='den Leeuwenburg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='ridderkasteel', types=['E19 Physical Thing']), Entity(span='Cassel', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='eenige jaren', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='15de Eeuw', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='de burg zelve', types=['E53 Place', 'E19 Physical Thing']), Entity(span='twee torens', types=['E19 Physical Thing']), Entity(span='de eene', types=['E19 Physical Thing']), Entity(span='de andere', types=['E19 Physical Thing']), Entity(span='de puinen', types=['E19 Physical Thing']), Entity(span='gracht', types=['E19 Physical Thing']), Entity(span='ophaalbrug', types=['E19 Physical Thing']), Entity(span='poort', types=['E19 Physical Thing']), Entity(span='2 schildwagten', types=['E74 Group']), Entity(span='hellebaarden', types=['E19 Physical Thing']), Entity(span='Burggraaf', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='dees man', types=['E21 Person']), Entity(span='den Burg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='kapel', types=['E19 Physical Thing']), Entity(span='stal', types=['E19 Physical Thing']), Entity(span='warenkamer', types=['E19 Physical Thing']), Entity(span='woning van de opziener', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='paardestal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='wapenkamer', types=['E53 Place', 'E19 Physical Thing']), Entity(span='harnassen', types=['E19 Physical Thing']), Entity(span='lancen', types=['E19 Physical Thing']), Entity(span='zwaarden', types=['E19 Physical Thing']), Entity(span='paard', types=['E19 Physical Thing']), Entity(span='ridder', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Gothische', types=['E19 Physical Thing']), Entity(span='een uit steen gehouwen geharnast ridder', types=['E19 Physical Thing', 'E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Keurvorst', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='om de 14 dagen', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='burgplein', types=['E53 Place', 'E19 Physical Thing']), Entity(span='hoofdgebouw', types=['E19 Physical Thing']), Entity(span='borstbeeld', types=['E19 Physical Thing']), Entity(span='geharnast ridder', types=['E21 Person']), Entity(span='huisraad', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Hessische vorsten', types=['E74 Group']), Entity(span='riddertyden', types=['E52 Time-Span']), Entity(span='riddergeschiedenissen', types=['E52 Time-Span']), Entity(span='14de en 15de Eeuwen', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Eetzaal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='ridderzaal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='groote verzameling', types=['E74 Group']), Entity(span='zeer groote', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='bibliotheek', types=['E53 Place', 'E19 Physical Thing']), Entity(span='ridderromans', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Hieronymus', types=['E21 Person']), Entity(span='Löwenburg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='spook', types=['E19 Physical Thing']), Entity(span='koets', types=['E19 Physical Thing']), Entity(span='twee jaren', types=['E54 Dimension']), Entity(span='Wilhelmhöhe', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Octogoon', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hercules', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Cassel', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='900 trappen', types=['E54 Dimension']), Entity(span='2000 voet', types=['E54 Dimension']), Entity(span='anderhalf uur', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Cassel', types=['E53 Place']), Entity(span='Steinhöfer Wasserfall', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='296 trappen', types=['E54 Dimension']), Entity(span='reuzengevaarte', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Havikswoud', types=['E53 Place']), Entity(span='Octogoon', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='een grootte en breedte van verscheiden honderd voeten', types=['E54 Dimension']), Entity(span='700 voeten lengte & 300 voeten breedte', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='1696', types=['E52 Time-Span']), Entity(span='1714', types=['E52 Time-Span']), Entity(span='landgraaf Karel', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='40 voeten', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Octogoon', types=['E19 Physical Thing']), Entity(span='Keurvorst', types=['E21 Person']), Entity(span='zaal', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='192 te zamen vereenigde pylasters', types=['E54 Dimension']), Entity(span='48 voet hoog', types=['E54 Dimension']), Entity(span='balustrade', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='96 voet hoog', types=['E54 Dimension']), Entity(span='elf voeten hooge', types=['E54 Dimension']), Entity(span='pyramide', types=['E19 Physical Thing']), Entity(span='den knods van Hercules', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Dit metalen beeld', types=['E19 Physical Thing']), Entity(span='30 voet hoog', types=['E54 Dimension']), Entity(span='Hercules van Farnese', types=['E19 Physical Thing']), Entity(span='1717', types=['E52 Time-Span']), Entity(span='de pyramide', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='gezelschap', types=['E74 Group']), Entity(span='vengsterske', types=['E19 Physical Thing']), Entity(span='10 Groningers', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Hercules', types=['E21 Person']), Entity(span='zyne onderdanen', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Octogoon', types=['E53 Place', 'E19 Physical Thing']), Entity(span='een menigte menschen', types=['E74 Group']), Entity(span='waterwerken', types=['E19 Physical Thing']), Entity(span='groote omwegen', types=['E54 Dimension']), Entity(span='rytuig', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Euceladus', types=['E21 Person']), Entity(span='Octogoon', types=['E19 Physical Thing']), Entity(span='55 voet', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='bedriegertjes', types=['E74 Group']), Entity(span='grot van Polypheem', types=['E53 Place', 'E19 Physical Thing']), Entity(span='waterorgel', types=['E19 Physical Thing']), Entity(span='drie dames', types=['E74 Group']), Entity(span='naar eene andere kant gaande', types=['E9 Move'])]),
#  EntityOutput(entities=[Entity(span='cascade van de winterkasten', types=['E19 Physical Thing']), Entity(span='de leiding', types=['E19 Physical Thing']), Entity(span='zyde der trappen', types=['E19 Physical Thing']), Entity(span='deeze massa water', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='800 voeten', types=['E54 Dimension']), Entity(span='20 voet hoog met eene breedte van 40 voet', types=['E54 Dimension']), Entity(span='grot van Neptunus', types=['E53 Place', 'E19 Physical Thing']), Entity(span='220 voeten diameter', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Duivelsbrug', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Teufelsbrücke', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Zwitserland', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Aqueduct', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='tyden der oude Romeinen', types=['E52 Time-Span']), Entity(span='14 gewelfde bogen', types=['E54 Dimension']), Entity(span='30 voet breed en eene diepte van 104 voeten', types=['E54 Dimension']), Entity(span='¾ uur lang', types=['E54 Dimension']), Entity(span='196 voeten', types=['E54 Dimension']), Entity(span='Keurvorst', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Wilhelmshöhe', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='schouwburg', types=['E19 Physical Thing']), Entity(span='slot', types=['E19 Physical Thing']), Entity(span='Comedie', types=['E19 Physical Thing']), Entity(span='Chinesche dorp Mu-lang', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='diergaarde', types=['E53 Place']), Entity(span='harten', types=['E21 Person']), Entity(span='Rheëen', types=['E21 Person']), Entity(span='faisanten', types=['E21 Person']), Entity(span='dieren', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Vergilius', types=['E21 Person']), Entity(span='Apollo', types=['E21 Person']), Entity(span='Mercurius', types=['E21 Person']), Entity(span='Felseneck', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Pluto', types=['E21 Person']), Entity(span='Elisesche velden', types=['E53 Place']), Entity(span='Hemel en Aard Goden en Godinnen', types=['E74 Group']), Entity(span='Wilhelmhöhe', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='een oogenblik', types=['E54 Dimension']), Entity(span='des avonds 8 uur', types=['E52 Time-Span']), Entity(span='een oogenblik', types=['E54 Dimension']), Entity(span='9 uren', types=['E54 Dimension']), Entity(span='Cassel', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='den 8 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='gisteren', types=['E52 Time-Span']), Entity(span='Cassel', types=['E53 Place']), Entity(span='de Heeren de Geer, Tydeman en van Swinderen', types=['E74 Group']), Entity(span='van de morgen vroeg', types=['E52 Time-Span']), Entity(span='observatorium', types=['E19 Physical Thing']), Entity(span='modelle huis', types=['E19 Physical Thing']), Entity(span='Hogendorp', types=['E21 Person']), Entity(span='Heer van Assen', types=['E21 Person']), Entity(span='Heer de Geer', types=['E21 Person']), Entity(span='Cassel', types=['E53 Place']), Entity(span='’t Vaderland', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='sterrewagt', types=['E19 Physical Thing']), Entity(span='Cassel', types=['E53 Place']), Entity(span='Aue Garten', types=['E53 Place']), Entity(span='Wilhelmshöhe', types=['E53 Place']), Entity(span='wandeld zyn', types=['E9 Move'])]),
#  EntityOutput(entities=[Entity(span='Fulda', types=['E53 Place']), Entity(span='Aue Garten', types=['E53 Place']), Entity(span='Orangerie', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Des avonds', types=['E52 Time-Span']), Entity(span='4 uur', types=['E52 Time-Span']), Entity(span='den Heer van Assen', types=['E21 Person']), Entity(span='drie uur', types=['E52 Time-Span']), Entity(span='Cassel', types=['E53 Place']), Entity(span='den 9 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Cassel', types=['E53 Place']), Entity(span='Wolfsänger', types=['E53 Place']), Entity(span='Bökshausen', types=['E53 Place']), Entity(span='Munden', types=['E53 Place']), Entity(span='Fulda', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Munden', types=['E53 Place']), Entity(span='Fulda', types=['E53 Place']), Entity(span='Werra', types=['E53 Place']), Entity(span='Weser', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Munden', types=['E53 Place']), Entity(span='Hannoversch grondgebied', types=['E53 Place']), Entity(span='Hessische', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Unterschede', types=['E53 Place']), Entity(span='Grone', types=['E53 Place']), Entity(span='Dransfeld', types=['E53 Place']), Entity(span='Knalhutte', types=['E53 Place']), Entity(span='Gottingen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='voerman', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='een geruime tyd', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='11 uur', types=['E52 Time-Span']), Entity(span='10 uur', types=['E52 Time-Span']), Entity(span='de Kroon', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='Bibliotecks Gebäude', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place', 'E19 Physical Thing']), Entity(span='12 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='duration', types=['E52 Time-Span']), Entity(span='Hartzgebergte', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='7000 inwoners', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='bibliotheek', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='250,000 banden', types=['E54 Dimension']), Entity(span='1000 thaler of 1800 guldens', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='een tyd lang', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Göttinger Hoogleraaren', types=['E74 Group', 'E21 Person']), Entity(span='Haller', types=['E21 Person']), Entity(span='Heyne', types=['E21 Person']), Entity(span='Goede', types=['E21 Person']), Entity(span='Venus', types=['E19 Physical Thing']), Entity(span='Gladiator', types=['E19 Physical Thing']), Entity(span='12 Romeinsche Keisers', types=['E74 Group', 'E21 Person']), Entity(span='33 gewone & 7 buitengewone, Hoogleeraren', types=['E74 Group', 'E21 Person']), Entity(span='31 zoogenoemde privaat docenten', types=['E74 Group', 'E21 Person']), Entity(span='Professor', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Prof. Hugo', types=['E21 Person']), Entity(span='200', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Prof.', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='familie der Medicis', types=['E74 Group']), Entity(span='Catharina de vrouw van Hendrik de II', types=['E21 Person']), Entity(span='Corpus Iuris', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Heeren Graven', types=['E74 Group']), Entity(span='de overigen', types=['E74 Group']), Entity(span='inktkoker', types=['E19 Physical Thing']), Entity(span='stoel', types=['E19 Physical Thing']), Entity(span='breede tafel', types=['E19 Physical Thing']), Entity(span='banken', types=['E19 Physical Thing']), Entity(span='smalle lessenaars', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Professor Heeren', types=['E21 Person']), Entity(span='Prof. Bauer', types=['E21 Person']), Entity(span='Prof. Blumenbach', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Hoogleeraar van Swinderen', types=['E21 Person']), Entity(span='Blumenbach', types=['E21 Person']), Entity(span='7 Jaren', types=['E52 Time-Span']), Entity(span='Gottingen', types=['E53 Place']), Entity(span='ZynHoogGeleerde', types=['E21 Person']), Entity(span='Heren Reizigers', types=['E74 Group']), Entity(span='1809', types=['E52 Time-Span']), Entity(span='1ste deel', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Prof. van Swinderen', types=['E21 Person']), Entity(span='logement', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Hofraad Blumenbach', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='schedelcabinet', types=['E19 Physical Thing']), Entity(span='gisteren', types=['E52 Time-Span']), Entity(span='schedels', types=['E19 Physical Thing']), Entity(span='volkeren der aarde', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Edele Heer Hofraad', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='vogelbekdier', types=['E19 Physical Thing']), Entity(span='Nieuw Holland', types=['E53 Place']), Entity(span='Blum', types=['E21 Person']), Entity(span='barnsteenboom', types=['E19 Physical Thing']), Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='tooren', types=['E19 Physical Thing']), Entity(span='vest', types=['E53 Place', 'E19 Physical Thing']), Entity(span='muur quadrant', types=['E19 Physical Thing']), Entity(span='telescoop', types=['E19 Physical Thing']), Entity(span='10 voeten', types=['E54 Dimension']), Entity(span='28 voeten', types=['E54 Dimension']), Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='100,000 thaler', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Entbindungs-Haus', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Prof. Osiander', types=['E21 Person']), Entity(span='la Faille', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Museum', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Prof. Hausman', types=['E21 Person']), Entity(span='vogels', types=['E19 Physical Thing']), Entity(span='kamer met rariteiten', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Suidzee', types=['E53 Place']), Entity(span='Sandwich’s eilanden', types=['E53 Place']), Entity(span='schilderyen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Gottingen', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='de Lange', types=['E21 Person']), Entity(span='Groningen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Gisteren', types=['E52 Time-Span']), Entity(span='verliet', types=['E86 Leaving']), Entity(span='Heer de Geer', types=['E21 Person']), Entity(span='Munster', types=['E53 Place']), Entity(span='reisgenoot', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='ZynEd', types=['E21 Person']), Entity(span='Cassel', types=['E53 Place']), Entity(span='Hr van Assen', types=['E21 Person']), Entity(span='Francfort', types=['E53 Place']), Entity(span='1 Augustus', types=['E52 Time-Span']), Entity(span='Haarlem', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='myn Vriend', types=['E21 Person']), Entity(span='Gottingen', types=['E53 Place']), Entity(span='morgen', types=['E52 Time-Span']), Entity(span='4 uur', types=['E52 Time-Span']), Entity(span='Osterode', types=['E53 Place']), Entity(span='Hartz', types=['E53 Place']), Entity(span='Tydeman', types=['E21 Person']), Entity(span='Bodel', types=['E21 Person']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='Goslar', types=['E53 Place']), Entity(span='Brunwyk', types=['E53 Place']), Entity(span='16', types=['E52 Time-Span']), Entity(span='Maagdenburg', types=['E53 Place']), Entity(span='vertrekken', types=['E9 Move']), Entity(span='gaan', types=['E9 Move'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='morgens van den 15 July 1816 om 4½ uur', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Harz', types=['E53 Place']), Entity(span='reis', types=['E9 Move'])]),
#  EntityOutput(entities=[Entity(span='eenige honderd voet diep', types=['E54 Dimension']), Entity(span='mynen van Clauthal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='3400 voet', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='vertrek', types=['E86 Leaving'])]),
#  EntityOutput(entities=[Entity(span='verlieten', types=['E86 Leaving']), Entity(span='13 ll', types=['E52 Time-Span']), Entity(span='Göttingen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Osterode', types=['E53 Place']), Entity(span='Profr Hausman', types=['E21 Person']), Entity(span='eene menigte studenten', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Profr Tydeman', types=['E21 Person']), Entity(span='agter', types=['E86 Leaving']), Entity(span='volgende dag', types=['E52 Time-Span']), Entity(span='Bodel', types=['E21 Person']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='Brunswyk', types=['E53 Place']), Entity(span='Magdeburg', types=['E53 Place']), Entity(span='gaan', types=['E9 Move'])]),
#  EntityOutput(entities=[Entity(span='4 uur', types=['E52 Time-Span']), Entity(span='Angelstein', types=['E53 Place']), Entity(span='Plessa', types=['E53 Place']), Entity(span='7', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Grosenstheim', types=['E53 Place']), Entity(span='Suidheim', types=['E53 Place']), Entity(span='Nordheim', types=['E53 Place']), Entity(span='Cattenburg', types=['E53 Place']), Entity(span='Dorsten', types=['E53 Place']), Entity(span='12 uur', types=['E52 Time-Span']), Entity(span='Osterode', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Clausthal', types=['E53 Place']), Entity(span='Harz', types=['E53 Place']), Entity(span='Osterode', types=['E53 Place']), Entity(span='Hartsgebergte', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Clausthal', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='2 uur', types=['E52 Time-Span']), Entity(span='4 paarden', types=['E19 Physical Thing']), Entity(span='de bergen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='eene peillooze afgrond', types=['E19 Physical Thing']), Entity(span='het eene paard', types=['E19 Physical Thing']), Entity(span='de drie overige', types=['E74 Group']), Entity(span='de wagen', types=['E19 Physical Thing']), Entity(span='onzen postiljon', types=['E21 Person']), Entity(span='het paard', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Lerbach', types=['E53 Place']), Entity(span='100 huizen', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='5 uuren', types=['E52 Time-Span']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='de Kroon', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Kastelein Smith', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='loodmynen', types=['E53 Place', 'E19 Physical Thing']), Entity(span='permissebiljet', types=[]), Entity(span='bergambt', types=['E21 Person']), Entity(span='Oberbergmeister', types=['E21 Person']), Entity(span='Hüttenreiter', types=['E21 Person']), Entity(span='Münzmeister', types=['E21 Person']), Entity(span='Gruben', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Puchwerke', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hütten', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Münze', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='gingen wy', types=['E9 Move', 'E86 Leaving']), Entity(span='Zellerfeld', types=['E53 Place']), Entity(span='¾ uur', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='mynwerkers', types=['E74 Group']), Entity(span='myn', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='een kwartier lang', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Caroliner groef', types=['E53 Place', 'E19 Physical Thing']), Entity(span='mijnen', types=['E53 Place', 'E19 Physical Thing']), Entity(span='waterleidingen', types=['E19 Physical Thing']), Entity(span='stollen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='30 voet hoger', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='6 voet wydte en 7 a 8 voet hoogte', types=['E54 Dimension']), Entity(span='Tiefer Georg Stollen', types=['E19 Physical Thing']), Entity(span='drie uur onder de bergen doorloopt', types=['E54 Dimension']), Entity(span='Grund', types=['E53 Place']), Entity(span='1777', types=['E52 Time-Span']), Entity(span='1800', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='18de brief', types=['E52 Time-Span']), Entity(span='reis door Duitsland', types=['E86 Leaving']), Entity(span='2de deel', types=['E52 Time-Span']), Entity(span='blad 19-49', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='geleider', types=['E21 Person']), Entity(span='mannetje', types=['E21 Person']), Entity(span='ladders', types=['E19 Physical Thing']), Entity(span='lamp', types=['E19 Physical Thing']), Entity(span='bergwerker', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='66 Lachter ieder a 7 voet & dus 462 voeten gedaald te hebben', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='erts', types=['E19 Physical Thing']), Entity(span='boccheljoentje', types=['E21 Person']), Entity(span='leidsman', types=['E21 Person']), Entity(span='machiene', types=['E19 Physical Thing']), Entity(span='myn', types=['E53 Place', 'E19 Physical Thing']), Entity(span='dagelyks', types=['E52 Time-Span']), Entity(span='6-9', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='34 jaar', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Zaturdag', types=['E52 Time-Span']), Entity(span='de 200 lachter of 1400 voet', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='geleider', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Dorotheengroef', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Hertog van Cambridge', types=['E21 Person']), Entity(span='vorige jaar', types=['E52 Time-Span']), Entity(span='Hertog', types=['E21 Person']), Entity(span='corps muzikanten', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='fauteuil', types=['E19 Physical Thing']), Entity(span='400 thaler', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Dorotheer groef', types=['E53 Place', 'E19 Physical Thing']), Entity(span='een kwartier verder', types=['E54 Dimension']), Entity(span='Caroliner', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Clausthal', types=['E53 Place']), Entity(span='donker wierd', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Munt', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hütten', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Zaturdag', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='half tienen', types=['E52 Time-Span']), Entity(span='30 menschen', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='logement', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Coffyhuis', types=['E53 Place', 'E19 Physical Thing']), Entity(span='billiart', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='hoogte van 293 toises of 1758 Parysche voeten', types=['E54 Dimension']), Entity(span='gansche zomer', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='verlieten wy', types=['E86 Leaving']), Entity(span='half zes uur', types=['E52 Time-Span']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='gids', types=['E21 Person']), Entity(span='Andreasberg', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='eene vrouw', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='8 uur', types=['E52 Time-Span']), Entity(span='Damskruge', types=['E53 Place']), Entity(span='eenige jagers', types=['E74 Group']), Entity(span='een party honden', types=['E74 Group']), Entity(span='harten', types=['E19 Physical Thing']), Entity(span='Rheëen', types=['E19 Physical Thing']), Entity(span='hazen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='half tien', types=['E52 Time-Span']), Entity(span='Schluss', types=['E53 Place', 'E19 Physical Thing']), Entity(span='herberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='geruime tyd', types=['E54 Dimension']), Entity(span='anderhalf uur', types=['E52 Time-Span']), Entity(span='Andreasberg', types=['E53 Place']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='1817 voet', types=['E54 Dimension']), Entity(span='Oostzee', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='de persoon van de kastelein', types=['E21 Person']), Entity(span='Oderbrücke', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='H.', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Der Rehberger Graben', types=['E53 Place']), Entity(span='Der Rehbergergraben am Harz', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='mynen te Clauthal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='vorige dag', types=['E52 Time-Span']), Entity(span='Mayer', types=['E21 Person']), Entity(span='opzoeken', types=['E9 Move']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Profr Hausman', types=['E21 Person']), Entity(span='Göttingen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Rehberger Graben', types=['E19 Physical Thing']), Entity(span='vertrokken wy', types=['E86 Leaving']), Entity(span='1 uur', types=['E52 Time-Span']), Entity(span='korfwagen', types=['E19 Physical Thing']), Entity(span='Andreasberg', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Mayer', types=['E21 Person']), Entity(span='wagen', types=['E19 Physical Thing']), Entity(span='waterleidingen', types=['E19 Physical Thing']), Entity(span='13,000 thalers', types=['E54 Dimension']), Entity(span='bergen', types=['E53 Place']), Entity(span='mijnen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Rehberger graben', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Rehberger klippen', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Zwitsersche party', types=['E53 Place']), Entity(span='Kaale rots', types=['E19 Physical Thing']), Entity(span='dennebomen', types=['E19 Physical Thing']), Entity(span='waterval', types=['E19 Physical Thing']), Entity(span='slagboom', types=['E19 Physical Thing']), Entity(span='gids', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Hanetree', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Koningsberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='pistool', types=['E19 Physical Thing']), Entity(span='drie maal toe', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Oder', types=['E53 Place', 'E19 Physical Thing']), Entity(span='7 uuren', types=['E54 Dimension']), Entity(span='Oderteich', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Odendam', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='de grootvader', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Rehberger graben', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='3 uur', types=['E52 Time-Span']), Entity(span='Oderbrücke', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='voerman', types=['E21 Person']), Entity(span='terug reed', types=['E86 Leaving']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='de vorige winter', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Mayer', types=['E21 Person']), Entity(span='kleinen Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='voor 5 dagen', types=['E52 Time-Span']), Entity(span='eene plaats', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Brokken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='te beklimmen', types=['E9 Move'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='H.', types=['E21 Person']), Entity(span='tien schreden', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='3480 voet', types=['E54 Dimension']), Entity(span='herberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='dezen nagt', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Graaf van Stolberg Heer van Wernigerode', types=['E21 Person']), Entity(span='jaar 1800', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='19,000 Thaler', types=['E54 Dimension']), Entity(span='12 kamers', types=['E54 Dimension']), Entity(span='vyf voet dik', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='gingen wy', types=['E9 Move']), Entity(span='Heksen altaar', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Duivels kansel', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Heksen dansplaats', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Wolkenhuisje', types=['E53 Place', 'E19 Physical Thing']), Entity(span='laatsten April', types=['E52 Time-Span']), Entity(span='St Walburgs nagt', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Sneeuw loch', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Mayer', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Mayer', types=['E21 Person']), Entity(span='herberg de Oberbrücke', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hartsgebergte', types=['E53 Place']), Entity(span='Profr Hausman', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='schaapvleesch soep', types=[]), Entity(span='blaauwe besieën', types=[]), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='albums van reizigers', types=[])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Gegend von Wernigerode', types=['E53 Place']), Entity(span='12 Morgen', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Voor Zonnen opgang', types=['E52 Time-Span']), Entity(span='gisteren', types=['E52 Time-Span']), Entity(span='23 uren', types=['E54 Dimension']), Entity(span='1662 vierkante uren', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='verlaten', types=['E86 Leaving']), Entity(span='waard', types=['E21 Person']), Entity(span='3 zomer maanden woont', types=['E52 Time-Span']), Entity(span='knegt', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Elbrugerode', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Maagdeburg', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Wernigerode', types=['E53 Place']), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='herbergier', types=['E21 Person']), Entity(span='Ezel', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Jerome Napoleon', types=['E21 Person']), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='twaalftal ruiters', types=['E74 Group'])])]

# %%
from tqdm import trange

responses_oai = []

client_oai = OpenAI()
oai_model = "gpt-4o-mini"

for idx in trange(len(df_test)):

    system_prompt = system_prompt_template.format(
        format_examples(df_train.iloc[indices[idx]])
    )

    completion = client_oai.beta.chat.completions.parse(
        model=oai_model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": df_test.iloc[idx]["text"]},
        ],
        response_format=EntityOutput,
    )

    responses_oai.append(completion.choices[0].message.parsed)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 223/223 [04:47<00:00,  1.29s/it]

# %%
responses_oai
# Out:
# [EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='den 9 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Wilhelmshöhe', types=['E53 Place']), Entity(span='Weissenstein', types=['E53 Place']), Entity(span='een groot uur', types=['E52 Time-Span']), Entity(span='de stad', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Karel', types=['E21 Person']), Entity(span='Frederik de II', types=['E21 Person']), Entity(span='Willem de IX', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Zondag ll', types=['E52 Time-Span']), Entity(span='Weissenstein', types=['E53 Place']), Entity(span='waterwerken', types=['E19 Physical Thing']), Entity(span='inwoners der stad', types=['E74 Group']), Entity(span='vreemdelingen', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Casernes', types=['E19 Physical Thing']), Entity(span='30,000 man', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='paleis', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Wilhelmshöhe', types=['E53 Place']), Entity(span='Gulielmus IX Elector', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='62 voeten doorsnede', types=['E54 Dimension']), Entity(span='Cassel', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='danszaal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='galery van schilderyen', types=['E53 Place', 'E19 Physical Thing']), Entity(span='7 voet breed', types=['E54 Dimension']), Entity(span='9½ voet hoog', types=['E54 Dimension']), Entity(span='spyskamer', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Z Hoogheid', types=['E21 Person']), Entity(span='kleed', types=['E19 Physical Thing']), Entity(span='slaap', types=['E19 Physical Thing']), Entity(span='schryf', types=['E19 Physical Thing']), Entity(span='muziek kamer', types=['E53 Place', 'E19 Physical Thing']), Entity(span='slaapkamer van Hieronymus', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='bibliotheek', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='6 Groninger Menoniten', types=['E74 Group']), Entity(span='Cassel', types=['E53 Place']), Entity(span='Hr van Assen', types=['E21 Person']), Entity(span='Z.H. Prins Frederik', types=['E21 Person']), Entity(span='Student Hogendorp', types=['E21 Person']), Entity(span='1 Augustus', types=['E52 Time-Span']), Entity(span='den Haag', types=['E53 Place']), Entity(span='Francfort', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='gezelschap', types=['E74 Group']), Entity(span='bibliotheek', types=['E53 Place']), Entity(span='vertrek', types=['E19 Physical Thing']), Entity(span='de dubbele deuren', types=['E19 Physical Thing']), Entity(span='Hogendorp', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='hier', types=['E52 Time-Span']), Entity(span='een vengster', types=['E19 Physical Thing']), Entity(span='hoofdgebouw', types=['E53 Place']), Entity(span='verlieten', types=['E86 Leaving']), Entity(span='vleugels', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Titschbein', types=['E21 Person']), Entity(span='Gierusalemne liberata', types=['E19 Physical Thing']), Entity(span='Torquato Tasso', types=['E21 Person']), Entity(span='Wieland’s Oberon', types=['E19 Physical Thing']), Entity(span='beschrijving des Kurfürstlichen Landsitzes Wilhelmshöhe bey Cassel', types=['E19 Physical Thing']), Entity(span='1804', types=['E52 Time-Span']), Entity(span='W. Döring', types=['E21 Person']), Entity(span='Cassel', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Leeuwenburg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Cassel', types=['E53 Place']), Entity(span='een weinig ter linkerzyde', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='enige jaren', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='15de Eeuw', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='gebouw', types=['E19 Physical Thing']), Entity(span='burgtuin', types=['E19 Physical Thing']), Entity(span='tournooyveld', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='burg', types=['E19 Physical Thing']), Entity(span='torens', types=['E19 Physical Thing']), Entity(span='mos', types=['E19 Physical Thing']), Entity(span='puinen', types=['E19 Physical Thing']), Entity(span='gragt', types=['E19 Physical Thing']), Entity(span='ophaalbrug', types=['E19 Physical Thing']), Entity(span='poort', types=['E19 Physical Thing']), Entity(span='schildwagten', types=['E74 Group']), Entity(span='Burggraaf', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='dees man', types=['E21 Person']), Entity(span='Burg', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='vierenkante opene plaats', types=['E53 Place']), Entity(span='kapel', types=['E19 Physical Thing']), Entity(span='stal', types=['E19 Physical Thing']), Entity(span='warenkamer', types=['E19 Physical Thing']), Entity(span='woning van de opziener', types=['E19 Physical Thing']), Entity(span='gebouw', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='wapenkamer', types=['E53 Place']), Entity(span='meer dan levensgroot paard', types=['E19 Physical Thing', 'E54 Dimension']), Entity(span='ridder', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='de kapel', types=['E19 Physical Thing']), Entity(span='een uit steen gehouwen geharnast ridder', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Keurvorst', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='14 dagen', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='de leeraar', types=['E21 Person']), Entity(span='de dikke en digtbeschilderde glazen', types=['E19 Physical Thing']), Entity(span='het daglicht', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='burgplein', types=['E53 Place']), Entity(span='hoofdgebouw', types=['E19 Physical Thing']), Entity(span='geharnast ridder', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='oude Hessische vorsten', types=['E21 Person']), Entity(span='14de en 15de Eeuwen', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Eetzaal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='ridderzaal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='verzameling bocalen, hensen enz waaronder zeer groote', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='bibliotheek', types=['E53 Place', 'E19 Physical Thing']), Entity(span='ridderromans', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Hieronymus', types=['E21 Person']), Entity(span='Löwenburg', types=['E53 Place']), Entity(span='spook', types=['E19 Physical Thing']), Entity(span='twee jaren', types=['E52 Time-Span']), Entity(span='Wilhelmhöhe', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Octogoon', types=['E53 Place']), Entity(span='Hercules', types=['E53 Place']), Entity(span='Rhynwyn', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Cassel', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='900 trappen', types=['E54 Dimension']), Entity(span='2000 voet', types=['E54 Dimension']), Entity(span='anderhalf uur', types=['E52 Time-Span']), Entity(span='Cassel', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Cassel', types=['E53 Place']), Entity(span='Die Cascaden', types=['E19 Physical Thing']), Entity(span='Steinhöfer Wasserfall', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='296 trappen', types=['E54 Dimension']), Entity(span='reuzengevaarte', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Havikswoud', types=['E53 Place']), Entity(span='Octogoon', types=['E53 Place']), Entity(span='ten noodige tyde', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='verscheiden honderd voeten', types=['E54 Dimension']), Entity(span='700 voeten lengte', types=['E54 Dimension']), Entity(span='300 voeten breedte', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='den Octogoon', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='1696', types=['E52 Time-Span']), Entity(span='Karel', types=['E21 Person']), Entity(span='1714', types=['E52 Time-Span']), Entity(span='gewelven', types=['E19 Physical Thing']), Entity(span='rotsklompen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='de 40 voeten in omtrek', types=['E54 Dimension']), Entity(span='waterbak', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Octogoon', types=['E19 Physical Thing']), Entity(span='Keurvorst', types=['E21 Person']), Entity(span='zaal', types=['E19 Physical Thing']), Entity(span='heerlyk uitzigt', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='192 te zamen vereenigde pylasters', types=['E19 Physical Thing']), Entity(span='48 voet hoog', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='96 voet hoog', types=['E54 Dimension']), Entity(span='elf voeten hooge piëdestal', types=['E54 Dimension']), Entity(span='knods van Hercules', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='30 voet hoog', types=['E54 Dimension']), Entity(span='Hercules van Farnese', types=['E19 Physical Thing']), Entity(span='1717', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='gezelschap', types=['E74 Group']), Entity(span='10 Groningers', types=['E74 Group']), Entity(span='opklimmen der laatste vry smalle ladder', types=['E9 Move'])]),
#  EntityOutput(entities=[Entity(span='Hercules', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Octogoon', types=['E53 Place']), Entity(span='een menigte menschen', types=['E74 Group']), Entity(span='de waterwerken', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='fonteyn verbeeldende de kop van Euceladus', types=['E19 Physical Thing']), Entity(span='Octogoon', types=['E19 Physical Thing']), Entity(span='55 voet', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Polypheem', types=['E53 Place']), Entity(span='waterorgel', types=['E19 Physical Thing']), Entity(span='drie dames', types=['E74 Group']), Entity(span='kruisvuur der batteryen', types=['E19 Physical Thing']), Entity(span='naauwernood', types=['E52 Time-Span']), Entity(span='een menigte', types=['E74 Group']), Entity(span='eerste', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='cascade van de winterkasten', types=['E19 Physical Thing']), Entity(span='de leiding op zyde der trappen', types=['E19 Physical Thing']), Entity(span='heerlyk gezicht', types=['E19 Physical Thing']), Entity(span='de zon', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='800 voeten', types=['E54 Dimension']), Entity(span='Neptunus', types=['E53 Place']), Entity(span='20 voet hoog', types=['E54 Dimension']), Entity(span='40 voet', types=['E54 Dimension']), Entity(span='groote waterbak', types=['E19 Physical Thing']), Entity(span='220 voeten diameter', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='waterval', types=['E19 Physical Thing']), Entity(span='Duivelsbrug', types=['E53 Place']), Entity(span='Teufelsbrücke', types=['E53 Place']), Entity(span='Zwitserland', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='rotsklompen', types=['E19 Physical Thing']), Entity(span='water', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='waterval van den zoogenaamde Aqueduct', types=['E19 Physical Thing']), Entity(span='Cassel', types=['E53 Place']), Entity(span='Aquaduct', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='14 gewelfde bogen', types=['E19 Physical Thing']), Entity(span='30 voet breed', types=['E54 Dimension']), Entity(span='104 voeten', types=['E54 Dimension']), Entity(span='¾ uur lang', types=['E54 Dimension']), Entity(span='groote fonteyn', types=['E19 Physical Thing']), Entity(span='geruime afstand', types=['E54 Dimension']), Entity(span='196 voeten', types=['E54 Dimension']), Entity(span='waterval van den Aqueduct', types=['E19 Physical Thing']), Entity(span='Keurvorst', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='fonteyn', types=['E19 Physical Thing']), Entity(span='Wilhelmshöhe', types=['E53 Place']), Entity(span='herberg', types=['E53 Place']), Entity(span='bomen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Felseneck an der Wilhelmshöhe', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Chinees gebouw', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Comedie', types=['E53 Place']), Entity(span='Chinesche dorp Mu-lang', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='diergaarde', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Rheëen', types=['E19 Physical Thing']), Entity(span='faisanten', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='het graf van Vergilius', types=['E19 Physical Thing']), Entity(span='de tempel van Apollo', types=['E19 Physical Thing']), Entity(span='de tempel van Mercurius', types=['E19 Physical Thing']), Entity(span='de Felseneck', types=['E53 Place', 'E19 Physical Thing']), Entity(span='de grot van Pluto', types=['E53 Place', 'E19 Physical Thing']), Entity(span='de Elisesche velden', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hemel', types=['E74 Group']), Entity(span='Aard Goden en Godinnen', types=['E74 Group']), Entity(span='Wilhelmhöhe', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Weissenstein', types=['E53 Place']), Entity(span='Cassel', types=['E53 Place']), Entity(span='8 uur', types=['E52 Time-Span']), Entity(span='9 uren', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='8 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='gisteren', types=['E52 Time-Span']), Entity(span='Cassel', types=['E53 Place']), Entity(span='Heeren de Geer', types=['E21 Person']), Entity(span='Tydeman', types=['E21 Person']), Entity(span='van Swinderen', types=['E21 Person']), Entity(span='observatorium', types=['E19 Physical Thing']), Entity(span='modelle huis', types=['E19 Physical Thing']), Entity(span='Hogendorp', types=['E21 Person']), Entity(span='Heer van Assen', types=['E21 Person']), Entity(span='de Geer', types=['E21 Person']), Entity(span='t Vaderland', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='sterrewagt', types=['E53 Place']), Entity(span='Cassel', types=['E53 Place']), Entity(span='Aue Garten', types=['E53 Place']), Entity(span='Wilhelmshöhe', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Fulda', types=['E53 Place']), Entity(span='Aue Garten', types=['E53 Place']), Entity(span='Orangerie', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='4 uur', types=['E52 Time-Span']), Entity(span='den Heer van Assen', types=['E21 Person']), Entity(span='drie uur', types=['E52 Time-Span']), Entity(span='Cassel', types=['E53 Place']), Entity(span='9 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Cassel', types=['E53 Place']), Entity(span='Wolfsänger', types=['E53 Place']), Entity(span='Bökshausen', types=['E53 Place']), Entity(span='Munden', types=['E53 Place']), Entity(span='Fulda', types=['E53 Place']), Entity(span='een hooge berg', types=['E19 Physical Thing']), Entity(span='een sneeuwwit huisje', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Munden', types=['E53 Place']), Entity(span='dal', types=['E53 Place']), Entity(span='Fulda', types=['E53 Place']), Entity(span='Werra', types=['E53 Place']), Entity(span='Weser', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Munden', types=['E53 Place']), Entity(span='Hannoversch', types=['E53 Place']), Entity(span='Hessische', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Unterschede', types=['E53 Place']), Entity(span='Grone', types=['E53 Place']), Entity(span='Dransfeld', types=['E53 Place']), Entity(span='Knalhutte', types=['E53 Place']), Entity(span='Gottingen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='deze berg', types=['E53 Place']), Entity(span='voerman', types=['E21 Person']), Entity(span='uit de wagen', types=['E86 Leaving'])]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='geruime tijd', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='11 uur', types=['E52 Time-Span']), Entity(span='10 uur', types=['E54 Dimension']), Entity(span='de Kroon', types=['E53 Place']), Entity(span='derwaarts', types=['E9 Move'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='Bibliotecks Gebäude', types=['E19 Physical Thing']), Entity(span='Göttingen', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='den 12 July 1816', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place']), Entity(span='Hartzgebergte', types=['E53 Place']), Entity(span='duration', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='7000 inwoners', types=['E74 Group']), Entity(span='Hoogeschool', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='schoone bibliotheek', types=['E53 Place']), Entity(span='onafmeetbare zalen', types=['E19 Physical Thing', 'E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Dresden', types=['E53 Place']), Entity(span='meer dan 250,000 banden', types=['E54 Dimension']), Entity(span='Denon les Antiquités Egyptiennes', types=['E19 Physical Thing']), Entity(span='1000 thaler of 1800 guldens', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Professoren Reuss', types=['E21 Person']), Entity(span='Benecke', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Göttinger Hoogleraaren', types=['E21 Person']), Entity(span='Haller', types=['E21 Person']), Entity(span='Heyne', types=['E21 Person']), Entity(span='Goede', types=['E21 Person']), Entity(span='Venus', types=['E19 Physical Thing']), Entity(span='Gladiator', types=['E19 Physical Thing']), Entity(span='12 Romeinsche Keisers', types=['E19 Physical Thing']), Entity(span='33 gewone & 7 buitengewone', types=['E74 Group']), Entity(span='31 zoogenoemde privaat docenten', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Prof. Hugo', types=['E21 Person']), Entity(span='200', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Prof.', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='de familie der Medicis', types=['E74 Group']), Entity(span='Catharina de vrouw van Hendrik de II', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Heeren Graven', types=['E21 Person']), Entity(span='Studenten', types=['E74 Group']), Entity(span='banken', types=['E19 Physical Thing']), Entity(span='smalle lessenaars', types=['E19 Physical Thing']), Entity(span='eene afzonderlyke en gedistingueerde plaats', types=['E53 Place']), Entity(span='een inktkoker en stoel', types=['E19 Physical Thing']), Entity(span='breede tafel', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Professor Heeren', types=['E21 Person']), Entity(span='Prof. Bauer', types=['E21 Person']), Entity(span='Prof. Blumenbach', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='auditorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Professor', types=['E21 Person']), Entity(span='studenten', types=['E74 Group']), Entity(span='Hofraad Blumenbach', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Hoogleeraar van Swinderen', types=['E21 Person']), Entity(span='Gottingen', types=['E53 Place']), Entity(span='Heren Reizigers', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Prof. van Swinderen', types=['E21 Person']), Entity(span='logement', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Hofraad Blumenbach', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='zyn schedelcabinet', types=['E19 Physical Thing']), Entity(span='gestern', types=['E52 Time-Span']), Entity(span='schedels van alle volkeren der aarde', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Edele Heer Hofraad', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Nieuw Holland', types=['E53 Place']), Entity(span='Blum', types=['E21 Person']), Entity(span='barnsteenboom', types=['E19 Physical Thing']), Entity(span='Göttingen', types=['E53 Place']), Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='tooren', types=['E53 Place']), Entity(span='muur quadrant', types=['E19 Physical Thing']), Entity(span='telescoop', types=['E19 Physical Thing']), Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Vroedkunde', types=[]), Entity(span='Entbindungs-Haus', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Prof. Osiander', types=['E21 Person']), Entity(span='la Faille', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Museum', types=['E53 Place']), Entity(span='Prof. Hausman', types=['E21 Person']), Entity(span='Zuidzee', types=['E53 Place']), Entity(span='Sandwich’s eilanden', types=['E53 Place']), Entity(span='party schilderyen', types=['E74 Group'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Gottingen', types=['E53 Place']), Entity(span='studeren', types=['E9 Move'])]),
#  EntityOutput(entities=[Entity(span='het haar', types=['E19 Physical Thing']), Entity(span='voorhooft', types=['E19 Physical Thing']), Entity(span='krullen', types=['E19 Physical Thing']), Entity(span='rok', types=['E19 Physical Thing']), Entity(span='kwasten', types=['E19 Physical Thing']), Entity(span='strikken', types=['E19 Physical Thing']), Entity(span='lissen', types=['E19 Physical Thing']), Entity(span='linten', types=['E19 Physical Thing']), Entity(span='broek', types=['E19 Physical Thing']), Entity(span='kleur', types=['E19 Physical Thing']), Entity(span='laarzen', types=['E19 Physical Thing']), Entity(span='hoed', types=['E19 Physical Thing']), Entity(span='platte muts', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='de Lange', types=['E21 Person']), Entity(span='Groningen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Gisteren', types=['E52 Time-Span']), Entity(span='de Heer de Geer', types=['E21 Person']), Entity(span='Munster', types=['E53 Place']), Entity(span='reisgenoot', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Cassel', types=['E53 Place']), Entity(span='Hr van Assen', types=['E21 Person']), Entity(span='Francfort', types=['E53 Place']), Entity(span='1 Augustus', types=['E52 Time-Span']), Entity(span='Haarlem', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Gottingen', types=['E53 Place']), Entity(span='morgen', types=['E52 Time-Span']), Entity(span='4 uur', types=['E52 Time-Span']), Entity(span='Osterode', types=['E53 Place']), Entity(span='Hartz', types=['E53 Place']), Entity(span='Tydeman', types=['E21 Person']), Entity(span='Bodel', types=['E21 Person']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='Goslar', types=['E53 Place']), Entity(span='Brunwyk', types=['E53 Place']), Entity(span='16', types=['E52 Time-Span']), Entity(span='Maagdenburg', types=['E53 Place']), Entity(span='schryven', types=['E9 Move'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Duitsche', types=['E74 Group']), Entity(span='logement', types=['E19 Physical Thing']), Entity(span='tandepennetjes', types=['E19 Physical Thing']), Entity(span='dagelyks', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='morgens van den 15 July 1816 om 4½ uur', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Harz', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='eenige honderd voet diep', types=['E54 Dimension']), Entity(span='mynen van Clauthal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='3400 voet', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Göttingen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='verlieten', types=['E86 Leaving']), Entity(span='13 ll', types=['E52 Time-Span']), Entity(span='Göttingen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Osterode', types=['E53 Place']), Entity(span='Profr Hausman', types=['E21 Person']), Entity(span='eene menigte studenten', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='Profr Tydeman', types=['E21 Person']), Entity(span='agter', types=['E86 Leaving']), Entity(span='volgende dag', types=['E52 Time-Span']), Entity(span='Bodel', types=['E21 Person']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='Brunswyk', types=['E53 Place']), Entity(span='Magdeburg', types=['E53 Place']), Entity(span='gaan', types=['E9 Move'])]),
#  EntityOutput(entities=[Entity(span='4 uur', types=['E52 Time-Span']), Entity(span='Angelstein', types=['E53 Place']), Entity(span='Plessa', types=['E53 Place']), Entity(span='7', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Grosenstheim', types=['E53 Place']), Entity(span='Suidheim', types=['E53 Place']), Entity(span='Nordheim', types=['E53 Place']), Entity(span='Cattenburg', types=['E53 Place']), Entity(span='Dorsten', types=['E53 Place']), Entity(span='12 uur', types=['E52 Time-Span']), Entity(span='Osterode', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Clausthal', types=['E53 Place']), Entity(span='Harz', types=['E53 Place']), Entity(span='Osterode', types=['E53 Place']), Entity(span='Hartsgebergte', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Clausthal', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='2 uur', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Lerbach', types=['E53 Place']), Entity(span='100 huizen', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='5 uuren', types=['E52 Time-Span']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='de Kroon', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Kastelein Smith', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='loodmynen', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Erlaubniss schein', types=[]), Entity(span='permissebiljet', types=[]), Entity(span='bergambt', types=['E21 Person']), Entity(span='Oberbergmeister', types=['E21 Person']), Entity(span='Hüttenreiter', types=['E21 Person']), Entity(span='Münzmeister', types=['E21 Person']), Entity(span='Gruben', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Puchwerke', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hütten', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Münze', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='gingen wy', types=['E9 Move']), Entity(span='Zellerfeld', types=['E53 Place']), Entity(span='¾ uur', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='de weg derwaarts', types=['E53 Place']), Entity(span='het gebouw', types=['E19 Physical Thing']), Entity(span='de zaal', types=['E53 Place']), Entity(span='de mynwerkers', types=['E74 Group']), Entity(span='de myn', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='een kwartier lang', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='Caroliner groef', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='30 voet hoger', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='6 voet wydte en 7 a 8 voet hoogte', types=['E54 Dimension']), Entity(span='Tiefer Georg Stollen', types=['E19 Physical Thing']), Entity(span='drie uur onder de bergen doorloopt', types=['E54 Dimension']), Entity(span='Grund', types=['E53 Place']), Entity(span='1777', types=['E52 Time-Span']), Entity(span='1800', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='geleider', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='66 Lachter ieder a 7 voet & dus 462 voeten gedaald te hebben', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Zaturdag', types=['E52 Time-Span']), Entity(span='de 200 lachter of 1400 voet', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Dorotheengroef', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Hertog van Cambridge', types=['E21 Person']), Entity(span='vorige jaar', types=['E52 Time-Span']), Entity(span='Hertog', types=['E21 Person']), Entity(span='corps muzikanten', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='fauteuil', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Dorotheer groef', types=['E53 Place', 'E19 Physical Thing']), Entity(span='een kwartier verder', types=['E54 Dimension']), Entity(span='Caroliner', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Clausthal', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Munt', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hütten', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Zaturdag', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='half tienen', types=['E52 Time-Span']), Entity(span='30 menschen', types=['E74 Group'])]),
#  EntityOutput(entities=[Entity(span='logement', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Coffyhuis', types=['E53 Place', 'E19 Physical Thing']), Entity(span='billiart', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='hoogte van 293 toises of 1758 Parysche voeten', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='verlieten wy', types=['E86 Leaving']), Entity(span='half zes uur', types=['E52 Time-Span']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='gids', types=['E21 Person']), Entity(span='Andreasberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='eene vrouw', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='8 uur', types=['E52 Time-Span']), Entity(span='Damskruge', types=['E53 Place']), Entity(span='eenige jagers', types=['E74 Group'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='half tien', types=['E52 Time-Span']), Entity(span='Schluss', types=['E53 Place', 'E19 Physical Thing']), Entity(span='herberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='geruime tyd', types=['E54 Dimension']), Entity(span='anderhalf uur', types=['E54 Dimension']), Entity(span='Andreasberg', types=['E53 Place']), Entity(span='Clausthal', types=['E53 Place']), Entity(span='1817 voet', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='de persoon van de kastelein', types=['E21 Person']), Entity(span='Oderbrücke', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='H.', types=['E21 Person'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='mynen te Clauthal', types=['E53 Place', 'E19 Physical Thing']), Entity(span='vorige dag', types=['E52 Time-Span']), Entity(span='Mayer', types=['E21 Person']), Entity(span='opzoeken', types=['E9 Move']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Profr Hausman', types=['E21 Person']), Entity(span='Göttingen', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Rehberger Graben', types=['E19 Physical Thing']), Entity(span='vertrokken wy', types=['E86 Leaving']), Entity(span='1 uur', types=['E52 Time-Span']), Entity(span='korfwagen', types=['E19 Physical Thing']), Entity(span='Andreasberg', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Mayer', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Harz', types=['E53 Place']), Entity(span='Rehberger graben', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Rehberger klippen', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Kaale rots', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Hanetree', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Koningsberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Oder', types=['E53 Place', 'E19 Physical Thing']), Entity(span='7 uuren', types=['E54 Dimension']), Entity(span='Oderteich', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Odendam', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='diepte', types=['E19 Physical Thing']), Entity(span='de grootvader', types=['E21 Person']), Entity(span='voerman', types=['E21 Person']), Entity(span='paard', types=['E19 Physical Thing']), Entity(span='wagen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Rehberger graben', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='3 uur', types=['E52 Time-Span']), Entity(span='Oderbrücke', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='voerman', types=['E21 Person']), Entity(span='terug reed', types=['E86 Leaving']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Mayer', types=['E21 Person']), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='voor 5 dagen', types=['E52 Time-Span']), Entity(span='eene plaats', types=['E53 Place']), Entity(span='sneeuw', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Brokken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='H.', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='berg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='3480 voet', types=['E54 Dimension']), Entity(span='herberg', types=['E53 Place', 'E19 Physical Thing'])]),
#  EntityOutput(entities=[Entity(span='Graaf van Stolberg Heer van Wernigerode', types=['E21 Person']), Entity(span='jaar 1800', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='12 kamers', types=['E54 Dimension']), Entity(span='vyf voet dik', types=['E54 Dimension'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='gingen wy', types=['E9 Move']), Entity(span='Heksen altaar', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Duivels kansel', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Heksen dansplaats', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Wolkenhuisje', types=['E53 Place', 'E19 Physical Thing']), Entity(span='laatsten April', types=['E52 Time-Span']), Entity(span='St Walburgs nagt', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Sneeuw loch', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Mayer', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Mayer', types=['E21 Person']), Entity(span='herberg de Oberbrücke', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Bloksberg', types=['E53 Place', 'E19 Physical Thing']), Entity(span='Hartsgebergte', types=['E53 Place']), Entity(span='Profr Hausman', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='schaapvleesch soep', types=[]), Entity(span='blaauwe besieën', types=[]), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='observatorium', types=['E53 Place', 'E19 Physical Thing']), Entity(span='albums van reizigers', types=[])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Wernigerode', types=['E53 Place']), Entity(span='12 Morgen', types=['E19 Physical Thing'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Voor Zonnen opgang', types=['E52 Time-Span']), Entity(span='gisteren', types=['E52 Time-Span']), Entity(span='23 uren', types=['E54 Dimension']), Entity(span='1662 vierkante uren', types=['E54 Dimension'])]),
#  EntityOutput(entities=[Entity(span='verlaten', types=['E86 Leaving']), Entity(span='waard', types=['E21 Person']), Entity(span='3 zomer maanden woont', types=['E52 Time-Span'])]),
#  EntityOutput(entities=[Entity(span='Elbrugerode', types=['E53 Place'])]),
#  EntityOutput(entities=[Entity(span='Maagdeburg', types=['E53 Place'])]),
#  EntityOutput(entities=[]),
#  EntityOutput(entities=[Entity(span='Wernigerode', types=['E53 Place']), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing']), Entity(span='herbergier', types=['E21 Person'])]),
#  EntityOutput(entities=[Entity(span='Jerome Napoleon', types=['E21 Person']), Entity(span='Brocken', types=['E53 Place', 'E19 Physical Thing'])])]

# %%
response = responses[0]

# %%
response.model_dump()["entities"]
# Out:
# []

# %%
df_test
# Out:
#                                                   text  \
# 107                                      Vierde Brief.
# 108                        Göttingen den 9 July 1816 .
# 109                                   Waardste Vriend!
# 110  Wilhelmshöhe, voorheen Weissenstein genoemd en...
# 111  de landgraven Karel en Frederik de II hebben h...
# ..                                                 ...
# 325  ik zal deeze brief medenemen en dezelve te Elb...
# 326  Van Maagdeburg  hoop ik u te schryven en de dr...
# 327                                   [op linkerblad:
# 328  NB. Alleen van de zyde van Wernigerode  aan de...
# 329  Langs dat zelfde pad is Jerome Napoleon  tot e...
#
#                                                 labels  \
# 107                                                 []
# 108  [{'span': 'Göttingen', 'types': ['E53 Place']}...
# 109                                                 []
# 110  [{'span': 'Wilhelmshöhe', 'types': ['E53 Place...
# 111  [{'span': 'Karel', 'types': ['E21 Person']}, {...
# ..                                                 ...
# 325  [{'span': 'Elbrugerode', 'types': ['E53 Place']}]
# 326                                                 []
# 327                                                 []
# 328                                                 []
# 329  [{'span': 'Jerome Napoleon', 'types': ['E21 Pe...
#
#                              source  \
# 107  Ontology-based Annotation.docx
# 108  Ontology-based Annotation.docx
# 109  Ontology-based Annotation.docx
# 110  Ontology-based Annotation.docx
# 111  Ontology-based Annotation.docx
# ..                              ...
# 325  Ontology-based Annotation.docx
# 326  Ontology-based Annotation.docx
# 327  Ontology-based Annotation.docx
# 328  Ontology-based Annotation.docx
# 329  Ontology-based Annotation.docx
#
#                                         text_embedding
# 107  [0.038164765, 0.029106557, 0.0037032517, 0.026...
# 108  [-0.027040392, 0.053370032, -0.0045714774, 0.0...
# 109  [0.03379706, 0.020902578, 0.012958331, 0.01300...
# 110  [0.014872815, 0.052165806, -0.04137797, 0.0222...
# 111  [0.031060653, 0.05399668, -0.017590867, 0.0279...
# ..                                                 ...
# 325  [0.02856872, 0.03850489, -0.038084652, 0.01974...
# 326  [0.0014612004, 0.05482568, -0.01458141, 0.0023...
# 327  [0.026018828, 0.0623048, -0.016845644, 0.01691...
# 328  [0.006645154, 0.06859083, -0.0057803346, 0.035...
# 329  [0.021176355, 0.014847543, -0.011623593, 0.001...
#
# [223 rows x 4 columns]

# %%
df_out = df_test.copy()

# %%
df_out["mistral_small_3.2_output"] = [res.model_dump()["entities"] for res in responses]
df_out["gpt_4o_mini_output"] = [res.model_dump()["entities"] for res in responses_oai]

# %%
df_out[["text", "labels", "mistral_small_3.2_output", "gpt_4o_mini_output"]].to_json(
    "data/llm_predictions.jsonl", lines=True, orient="records", index=False
)

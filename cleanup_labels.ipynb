# %%
from pathlib import Path
import json

datadir = Path("data")
all_examples_file = datadir.joinpath("examples_to_clean.jsonl")

with all_examples_file.open("r", encoding="utf-8") as f:
    all_examples = [json.loads(line) for line in f]

# %%
all_examples
# Out:
# [{'text': 'Zesde Brief.',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Op de Bloksberg  des morgens van den 15 July 1816 om 4½ uur. –',
#   'labels': [{'span': 'Bloksberg',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'morgens van den 15 July 1816 om 4½ uur',
#     'types': ['E52 Time-Span']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Waardste Vriend!',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'U te melden wat wy deeze dagen op onze reis door den Harz gezien hebben, u hiervan een flaauwe allerflaauwste schets te geven is volstrekt onmogelyk! ',
#   'labels': [{'span': 'Harz', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Hoe zoude ik toch schriftelyk kunnen vermelden wat wy eenige honderd voet diep  in de mynen van Clauthal, en wat wy boven op den Bloksberg , meer dan 3400 voet  boven de oppervlakte van de Oostzee verheven gezien hebben; ',
#   'labels': [{'span': 'eenige honderd voet diep', 'types': ['E54 Dimension']},
#    {'span': 'mynen van Clauthal',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Bloksberg', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': '3400 voet', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'neen dat gaat niet aan, die hier van meer wil weten kome zelf hier deeze schoone natuurtoneelen in al haare pracht genieten; - ik zal u dus maar een droog relaas mededelen van het geen ons zedert ons vertrek uit Göttingen is wedervaren. –',
#   'labels': [{'span': 'Göttingen', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Zonder ontbeten te hebben, waartoe men ons te laat gewekt had, verlieten  wy den 13 ll  de stad stad Göttingen zeer te vreden over ons verblyf aldaar; ',
#   'labels': [{'span': 'verlieten', 'types': ['E86 Leaving']},
#    {'span': '13 ll', 'types': ['E52 Time-Span']},
#    {'span': 'Göttingen', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'met groote moeite hadden wy eenen wagen tot Osterode gekregen wyl Profr Hausman  dien dag met eene menigte studenten  eene botanische tour zoude doen, waartoe byna alle rytuigen besproken waren: ',
#   'labels': [{'span': 'Osterode', 'types': ['E53 Place']},
#    {'span': 'Profr Hausman', 'types': ['E21 Person']},
#    {'span': 'eene menigte studenten', 'types': ['E74 Group']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'wy lieten den Profr Tydeman  agter, die de volgende dag  Bodel  van Clausthal  zoude afhalen om over Brunswyk naar Magdeburg  te gaan. ',
#   'labels': [{'span': 'Profr Tydeman', 'types': ['E21 Person']},
#    {'span': 'agter', 'types': ['E86 Leaving']},
#    {'span': 'volgende dag', 'types': ['time']},
#    {'span': 'Bodel', 'types': ['E21 Person']},
#    {'span': 'Clausthal', 'types': ['E53 Place']},
#    {'span': 'Brunswyk', 'types': ['E53 Place']},
#    {'span': 'Magdeburg', 'types': ['E53 Place']},
#    {'span': 'gaan', 'types': ['E9 Move']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Om 4 uur  vertrokke zynde moesten wy, zonder iets te gebruiken, tot Angelstein doorryden, alwaar wy na Plessa  gepasseerd te zyn om 7  aankwamen en ons met een zeer sober ontbyt moesten vergenoegen: ',
#   'labels': [{'span': '4 uur', 'types': ['E52 Time-Span']},
#    {'span': 'Angelstein', 'types': ['E53 Place']},
#    {'span': 'Plessa', 'types': ['E53 Place']},
#    {'span': '7', 'types': ['E52 Time-Span']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'vervolgens door de dorpjes Grosenstheim  en langs Suidheim rydende bereikte wy het niet onaardig stadje Nordheim  alwaar wy stations geld moesten betalen; voor het overige ontmoette ons niets byzonders; na de dorpen Cattenburg  en Dorsten  gepasseerd te zyn kwamen wy circa 12 uur  te Osterode  aan. ',
#   'labels': [{'span': 'Grosenstheim', 'types': ['E53 Place']},
#    {'span': 'Suidheim', 'types': ['E53 Place']},
#    {'span': 'Nordheim', 'types': ['E53 Place']},
#    {'span': 'Cattenburg', 'types': ['E53 Place']},
#    {'span': 'Dorsten', 'types': ['E53 Place']},
#    {'span': '12 uur', 'types': ['E52 Time-Span']},
#    {'span': 'Osterode', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Schilderagtig is deeze bloeiende bergstad in eene vallei gelegen en alle bekoorlykst is het gezicht dat men van den steilen, blinkend witten gipsberg op dezelve heeft: de muren der huizen zyn alle helderwit en de daken met lei of zeer nette blaauwe plankjes bedekt: ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'jammer maar dat wy onder eene hevige regenbui aankwamen hetgeen ons verhinderde te voet naar Clausthal te gaan, daar wy [42] tot de reis door den Harz  weinig goed by ons hadden & ongaarne reeds den eersten dag doornat wilden zyn: te Osterode de voet van het Hartsgebergte  bereikt hebbende was die regen voor ons een malum omen gelukkig heeft het zich egter tot nu toe geschikt, en zyn wy in ons plan van reizen niet verhinderd geworden dan dat wy niet een rytuig in plaats van te voet naar Clausthal vertrokken. ',
#   'labels': [{'span': 'Clausthal', 'types': ['E53 Place']},
#    {'span': 'Harz', 'types': ['E53 Place']},
#    {'span': 'Osterode', 'types': ['E53 Place']},
#    {'span': 'Hartsgebergte', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Clausthal', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Na alvorens wat gegeten te hebben reden wy om 2 uur  met Extrapost af, de weg liep onophoudelyk steil tegen de bergen op zoodat onze 4 paarden dikwyls, zelfs als wy alle uit de wagen waren, de grootste moeite van de waereld hadden om de wagen er tegen op te trekken: ',
#   'labels': [{'span': '2 uur', 'types': ['E52 Time-Span']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'hierdoor hadden wy byna een groot ongeluk gekregen daar het eene paard op de rand van eene peillooze afgrond ophield met trekken waardoor de drie overige ter naauwernood de wagen konden houden, wy zaten alle in dezelve doch zommige onzer sprongen er op het voorbeeld van onzen postiljon af om het paard by den kop te krijgen: zeer flagmatiek zeide ons deeze dat het paard wel aan een soort van vallende ziekte onderhevig was en er dan zoo in eens maar nederviel, gelukkig dat hy het ons niet weder bakte. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Het dorpje Lerbach  uit 100 huizen  bestaande verraste ons door onverwagt uit eene diepe valley te voorschyn te komen, hier wonen, zoo als men zegt, verscheiden Albinos en de meeste vrouwen hebben hier even als in Zwitserland Kropgezwellen: ',
#   'labels': [{'span': 'Lerbach', 'types': ['E53 Place']},
#    {'span': '100 huizen', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'wy hadden echter geen tyd om ons van de waarheid daarvan te overtuigen wyl zulks ons te lang zoude ophouden. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[op linkerblad: ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Door allen die ons tegenkwamen wierden wy met een Glück auf begroet, zynde dit de gewoone en eenige groet van de bergwerkers.] ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Na nog aanhoudend geklommen en de schoonste gezigten gezien te hebben kwamen wy om 5 uuren  te Clausthal  de hoofdstad van den Harts aan en namen onzen intrek in de Kroon  by den Kastelein Smith. ',
#   'labels': [{'span': '5 uuren', 'types': ['E52 Time-Span']},
#    {'span': 'Clausthal', 'types': ['E53 Place']},
#    {'span': 'de Kroon', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Kastelein Smith', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Voornemens zynde om nog dien avond de loodmynen  in de nabyheid dier stad te bezigtigen, haasteden wy ons om ons van een zoogenaamd Erlaubniss schein of permissebiljet  te voozien hetwelk wy al spoedig van het bergambt  bekwamen & waarby de Oberbergmeister, Hüttenreiter & Münzmeister  bevolen wierden om door een hunner bedienden ons de Gruben, Puchwerke , Hütten  en Münze  te laten zien. ',
#   'labels': [{'span': 'loodmynen',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'permissebiljet', 'types': ['miscellaneous']},
#    {'span': 'bergambt', 'types': ['E21 Person']},
#    {'span': 'Oberbergmeister', 'types': ['E21 Person']},
#    {'span': 'Hüttenreiter', 'types': ['E21 Person']},
#    {'span': 'Münzmeister', 'types': ['E21 Person']},
#    {'span': 'Gruben', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Puchwerke', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Hütten', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Münze', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Hiermede gingen wy   [43] die naar het naburig Zellerfeld  was gewandelt) onder geleide van een gids naar de voornaamste ingang der mynen ongeveer ¾ uur  van de stad gelegen: ',
#   'labels': [{'span': 'gingen wy', 'types': ['E9 Move']},
#    {'span': 'Zellerfeld', 'types': ['E53 Place']},
#    {'span': '¾ uur', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'De weg derwaarts viel ons zeer kort en ras waren wy aan het gebouw genaderd en in de zaal gekomen alwaar de mynwerkers, eer zy in de myn gaan, hun gebed doen: hier wierden wy verzogt ons van onze boven kleederen te ontdoen welke alle met de goederen die wy in de zak hadden zorgvuldig wierden bewaard & hier gaf men ons elk een bergmans pak, in welk zonderling costuum de een den ander byna niet kende zoodat wy eerst een kwartier lang  nodig hadden om van lacchen te bedaren: verbeeld u uw Vriend gekleed in een wyde zwarte broek met knoopen aan weerszyde van onderen tot boven, een buis of kiel van dezelve stof insgelyks ryk met knopen bezet en tot de hals digt gemaakt, dit alles vry wat met opgedroogde klei en aarde besmeert daar deeze kleederen niet ieder reis gewasschen worden; daarby een zwart of groen vilten kapje op het hoofd zonder rand, en gy zult u my en myn bergmanspak tamelyk goed kunnen voorstellen. ',
#   'labels': [{'span': 'een kwartier lang', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Wy bekwamen hier elk een geleider waarmede wy uit het huis naar de ingang der Caroliner groef  gingen, hier zagen wy eerst hoe de armen der pompen, die de mynen van het overtollige water verlossen, & hetzelve tot de waterleidingen of stollen opvoeren, in beweging gebragt worden. ',
#   'labels': [{'span': 'Caroliner groef',
#     'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Wanneer de mond van de groef zoodanig gesteldt is dat er eene genoegzame hoeveelheid water van den berg af bylangs dezelve afloopt kan men terstond aldaar door een keerrad de pompen in beweging brengen, wanneer echter er op die plaats geen water is, uithoofde van de hooge ligging van den mond der mynen, dan plaatst men op lagere plaatsen dikwyls honderden roeden van daar zyne waterraden, welke tegen den berg oploopende jukken of trekbalansen, die in het midden op, in zekere afstanden van elkander geplaatste, spillen bewegen, zoodat de boven en onderstylen gedurig heen & weder gevoerd worden, die dan wederom aan den mond van den myn met een rad verbonden zyn, die de pompen in beweging brengt: ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'op dusdanige wyze was het aldaar ingerigt. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'De armen, waaraan deeze pompen verbonden zyn, dalen nu tot op den bodem van den groef [44] af waar de eerste pomp het water tot eene verzamelplaats omstreeks 30 voet hoger opvoert, wanneer wederom eene pomp aan dezelfde arm verbonden het water tot eene tweede vergaderplaats oppompt en zoo vervolgens totdat het door de stollen kan afloopen. ',
#   'labels': [{'span': '30 voet hoger', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Deeze stollen zyn waterleidingen in byna horizontale rigting een weinig aflopende tot buiten den berg gegraven het zyn galleryen van omstreeks 6 voet wydte en 7 a 8 voet hoogte  waar aan de eene zyde het water in eene breede goot afloopt een voetpad langs hetzelve open latende: de voornaamste dezer Stollen is de Tiefer Georg Stollen  welke meer dan drie uur onder de bergen doorloopt en by het stadje Grund  zyne uitwatering heeft men begon hier aan te werken in 1777 en eerst in 1800 was dezelve voltooid. ',
#   'labels': [{'span': '6 voet wydte en 7 a 8 voet hoogte',
#     'types': ['E54 Dimension']},
#    {'span': 'Tiefer Georg Stollen', 'types': ['E19 Physical Thing']},
#    {'span': 'drie uur onder de bergen doorloopt', 'types': ['E54 Dimension']},
#    {'span': 'Grund', 'types': ['E53 Place']},
#    {'span': '1777', 'types': ['E52 Time-Span']},
#    {'span': '1800', 'types': ['E52 Time-Span']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Dan wat behoef ik dit alles uitteleggen daar gy dit uit boeken kunt halen onder anderen uit de zeer omslagtige beschryving der mynen voorkomende in de 18de brief van de reis door Duitsland 2de deel van blad 19-49? ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'ik zal u dus maar verder met ons in de mynen voeren. – Nadat onze voornaamste geleider, zynde een klein krom gebocchelt mannetje, ons die werking van de pompen beduid had, opende hy het aklig hol, deed ons eene korte aanspraak, gaf ons eenige raad die wy in het dalen, en voornamentlyk in het vasthouden der ladders moesten in acht nemen, ontstak zyne lamp ’t geen ook de andere deden en daalde neder; niet zonder dat my de beenen wat knikten volgde ik hem; daarop weder een bergwerker; vervolgens een van ons en zoo vervolgens: ',
#   'labels': [{'span': 'geleider', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Spoedig verdween het daglicht en zagen wy ons in eene stikdonkere nagt verplaatst waarin ik niets zag dan de lampjes van myne compagnons die in een lange ry boven my flikkerden. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Verschriklyk was het schuren en kraken van de armen der pompen die agter ons werkten, en, als men in eene te kromme houding daalde, soms eene gevoelige dof op den rug gaven, vreeslyk klonk ook het rammelen der ketens aan de ledige en met erts gevulde emmers, die onophoudelyk op en neder gingen. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Wy hadden ons onder in de groef een [45]',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'rendez-vous gegeven waar wy dan ook na 66 Lachter ieder a 7 voet & dus 462 voeten gedaald te hebben by elkanderen kwamen zier verheugt zoo verre te zyn: ',
#   'labels': [{'span': '66 Lachter ieder a 7 voet & dus 462 voeten gedaald te hebben',
#     'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'op een stuk erts gezeten kregen wy hier het nodige onderricht van het boccheljoentje dat my als leidsman was ten deel gevallen en dat zich voordeet als het spil van het machiene waarop alles draaide, zoodat toen ik hem vroeg of hy dagelyks in de myn werkte, hy my met een paar groote oogen aanzag zeggende dat hy slechts iedere morgen van 6-9 beneden was um alles zu inspectieren; ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'werken was zyn character te na, dat had hy 34 jaar gedaan! ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Daar het juist Zaturdag  was vonden wy geene mynwerkers beneden, althans niet in de groef waar wy waren, zynde er verscheiden groeven boven elkanderen, en de diepste by de 200 lachter of 1400 voet; dan, daar alles voor het overige hetzelve was, besloten wy hier maar te blyven en deeze groef te bezichtigen: ',
#   'labels': [{'span': 'Zaturdag', 'types': ['time']},
#    {'span': 'de 200 lachter of 1400 voet', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'na dat wy er een eind in opgegaan waren ging myne vriendelyke geleider aan het werk toonde ons eerst hoe men een gat in eene schuinsche rigting in den gang boordt, hoe men hetzelve met buskruit vulde & de ingang op eene kleine opening voor den lont na, met steentjes digtmaakte hoe men, wanneer een stuk was losgesprongen, het met houweelen in kleinere stukken sloeg en deeze na de opening der myn naar de loodlynige put bragt van waar zy door middel der emmers naar boven gevoerd wierden, alsmede waar men de onnutte stof liet, die dadelyk voor niet metaalhoudend wierd erkent, dienende deeze gewoonlyk om de gemaakte gangen voor instorten te verzekeren. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Na hier alles gezien en een stukje erts mede genomen te hebben wandelden wy verder wanneer men ons in de stollen bragt terwyl onze leidsman zeide dat hy ons door dezelve naar de Dorotheengroef  zoude leiden. ',
#   'labels': [{'span': 'Dorotheengroef',
#     'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Aan de wanden deezer stollen zagen wy nog latten waar lampions gehongen hadden toen de Hertog van Cambridge het vorige jaar de mynen gevisiteerd had, gelyk wy mede eene groote plaats zynde als ’t ware een zaal bemerkten in de myn uitgehouwen & geheel met hout bekleed waar de Hertog gedejeuneerd had, wordende by die gelegenheid aangenaam verrast [46] door een heerlyk muziek hetwelk een talryk corps muzikanten in die onderaardsche holen had aangeheven en ’t geen uitmuntend voldaan had. ',
#   'labels': [{'span': 'Hertog van Cambridge', 'types': ['E21 Person']},
#    {'span': 'vorige jaar', 'types': ['time']},
#    {'span': 'Hertog', 'types': ['E21 Person']},
#    {'span': 'corps muzikanten', 'types': ['E74 Group']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'er stond nog een fauteuil by die gelegenheid door de mynwerkers uit erts gemaakt en aan innerlyke waarde 400 thaler waard. ',
#   'labels': [{'span': 'fauteuil', 'types': ['E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Eindelyk geraakten wy weder aan het klimmen ’t geen met vry wat meer moeite geschiede en niet zonder meenige zweetdroppel te laten vallen, gelukkig kwamen wy weder boven en wenschten elkander met de zoo wel volbragte togt geluk. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Wy waren de Dorotheer groef  uitgekomen en een kwartier verder de Caroliner ingegaan, wy zagen de rigting waarin wy langs gekomen waren en zulks was onder eene breede vloed door. ',
#   'labels': [{'span': 'Dorotheer groef',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'een kwartier verder', 'types': ['E54 Dimension']},
#    {'span': 'Caroliner', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Vrolyk ondeden wy ons van onze kleederen, bedankten en beloonden onze leidslieden voor hunne moeite en stapten wel gemoed voort om zoo spoedig mogelyk in Clausthal te zyn daar het reeds donker wierd: ',
#   'labels': [{'span': 'Clausthal', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'voornemens zynde om de volgende dag vroeg tydig te vertrekken konden wy de Munt  en zoogenaamde Hütten, waar het erts gesmolten en gezuiverd wordt, niet zien ook wierd aldaar uit hoofde der Zaturdag  niet gearbeit: ',
#   'labels': [{'span': 'Munt', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Hütten', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Zaturdag', 'types': ['time']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'over deeze hütte kund gy ook eene gansche brief in voornoemde reizen lezen 2 deel van bl 49 tot 63. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'In ons logement, alwaar wy over half tienen  aankwamen, vonden wy den hond in de pot zynde het souper byna geindigd er waren ongeveer 30 menschen aan de pulieque tavel. ',
#   'labels': [{'span': 'half tienen', 'types': ['E52 Time-Span']},
#    {'span': '30 menschen', 'types': ['E74 Group']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Het logement  was voortreflyk, onder vond men een goede zaal dienende tot Coffyhuis waar een billiart  Egeplaatst was. ',
#   'labels': [{'span': 'logement',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Coffyhuis', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'billiart', 'types': ['E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'De verandering van temperatuur was hier aanmerkelyk ook is de stad volgens de waarnemingen van Villefosse op de hoogte van 293 toises of 1758 Parysche voeten  boven de oppervlakte der Oostzee gelegen: in byna elken kamer zelfs in het armmoedigste huttje wierd een grootte kacchel gestookt hetgeen men ons zeide dat gedurende de gansche zomer plaats had, dit kwam ons vreemd over doch was ons met dat al zeer welkom.',
#   'labels': [{'span': 'hoogte van 293 toises of 1758 Parysche voeten',
#     'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '~', 'labels': [], 'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'De volgende morgen verlieten wy om half zes uur  Clausthal vergezeld van een gids  die ons naar Andreasberg zoude brengen doch by wien een van de vyf zinnen afwezig was en die daarna boven de weg ook niet ',
#   'labels': [{'span': 'verlieten wy', 'types': ['E86 Leaving']},
#    {'span': 'half zes uur', 'types': ['E52 Time-Span']},
#    {'span': 'Clausthal', 'types': ['E53 Place']},
#    {'span': 'gids', 'types': ['E21 Person']},
#    {'span': 'Andreasberg', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[47] wist zoodat wy daar lelyk mede opgescheept zouden geweest zyn zoo wy niet by geluk eene vrouw  aangetroffen hadden die mede derwaarts te voet ging en de weg kundig was, onzen gekke gids gebruikten wy toen alleen als lastezel om het pak te dragen. ',
#   'labels': [{'span': 'eene vrouw', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Steeds door bosschen gaande kwamen wy om 8 uur  te Damskruge  alwaar wy een oogenblik toefden en eenige jagers  ontmoette die van een party honden vergezeld in de bosschen gingen jagen die hier toch van harten, Rheëen en hazen wemelen schoon wy er geen gezien hebben, ook vind men er ',
#   'labels': [{'span': '8 uur', 'types': ['E52 Time-Span']},
#    {'span': 'Damskruge', 'types': ['E53 Place']},
#    {'span': 'eenige jagers', 'types': ['E74 Group']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'soms wilde zwynen doch in een klein aantal. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Door de schoonste & trotste gezichten opgetogen wandelden wy verder en bestegen een hemelhooge berg waar wy dikwyls in de laag hangende wolken waren en dezelve onder ons zagen: ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'langs de schoonste weg die men zich kan voorstellen kwamen wy om half tien  te Schluss zynde een herberg in een diep dal gelegen: ',
#   'labels': [{'span': 'half tien', 'types': ['E52 Time-Span']},
#    {'span': 'Schluss', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'wy hadden geen menschelyk wezen ontmoet zoodat wy er erg aan geweest zouden zyn indien wy met onzen gids alleen waren geweest. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Hier hielden wy ons weder een oogenblik op en bestegen toen weder den berg alwaar wy op een smal pad een geruime tyd  moesten wagten wyl ons hier eene menigte ezels tegenkwamen met lange zakken op den rug die juist de breedte van de weg besloegen zoodat wy niet passeren konden: hier ruischte een helder beekje waarvan het yskoude water heerlyk smaakte: na nog anderhalf uur  gewandelt te hebben kregen wy de stad Andreasberg  in het oog, dezelve is nog hoger als Clausthal  en wel 1817 voet  boven de Oostzee verheven, weldra waren wy in dezelve & het schoone logement binnen getreden. ',
#   'labels': [{'span': 'geruime tyd', 'types': ['E54 Dimension']},
#    {'span': 'anderhalf uur', 'types': ['E54 Dimension']},
#    {'span': 'Andreasberg', 'types': ['E53 Place']},
#    {'span': 'Clausthal', 'types': ['E53 Place']},
#    {'span': '1817 voet', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Alles beviel ons hier zeer wel vooral de persoon van de kastelein  dat een zeer vriendlyk mensch was & ons waarschuwde dat de voerman, om wien wy gezonden hadden, zich vry wat liet afdingen, zoodat wy ook van zyne eisch van 5 thaler om ons naar Oderbrücke te brengen meer dan de helft afdongen en hem voor 2 thaler engageerden: wy zouden gaarn ook dat traject te voet gedaan hebben dan onze reisgenoot ',
#   'labels': [{'span': 'de persoon van de kastelein', 'types': ['E21 Person']},
#    {'span': 'Oderbrücke', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'H.  was dood af, schoon hy zich op\xa0',
#   'labels': [{'span': 'H.', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[48]\xa0',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[illustraties op linker blad: Der Rehberger Graben en Der Rehbergergraben am Harz]\xa0',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'zyn lopen te voren vry wat beroemd had. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Daar wy de mynen te Clauthal de vorige dag gezien hadden lieten wy de mynen, die hier ook in menigte zyn, onbezogt, verkwikten ons in de herberg zoo goed mogelyk en gingen toen eenen Mayer  opzoeken om ons als gids by het bestygen der Bloksberg te dienen; ',
#   'labels': [{'span': 'mynen te Clauthal',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'vorige dag', 'types': ['time']},
#    {'span': 'Mayer', 'types': ['E21 Person']},
#    {'span': 'opzoeken', 'types': ['E9 Move']},
#    {'span': 'Bloksberg', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'deeze man was ons door Profr Hausman  uit Göttingen  aangevolen en naauwlyks had hy zulks gehoord of hy was buiten zich zelven van vreugd en beloofde ons dadelyk gereed te zullen zyn. ',
#   'labels': [{'span': 'Profr Hausman', 'types': ['E21 Person']},
#    {'span': 'Göttingen', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Na een permissie biljet bekomen te hebben om de weg bylangs de Rehberger Graben ,  ’t geen eene particuliere weg scheen te zyn, te mogen ryden vertrokken wy  om 1 uur  met een goede korfwagen  van Andreasberg : ',
#   'labels': [{'span': 'Rehberger Graben', 'types': ['E19 Physical Thing']},
#    {'span': 'vertrokken wy', 'types': ['E86 Leaving']},
#    {'span': '1 uur', 'types': ['E52 Time-Span']},
#    {'span': 'korfwagen', 'types': ['E19 Physical Thing']},
#    {'span': 'Andreasberg', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Mayer , die met ons op de wagen zat, toonde ons vooreerst de waterleidingen die met ongehoorde moeite en voor de som van 13,000 thalers van boven den eenen berg waren afgeleid en onder eenen anderen doorgevoerd om al het nodige tot de explotatie der mynen in beweging te brengen. ',
#   'labels': [{'span': 'Mayer', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Had ons tot nu toe de weg door de Harz schoon toegeleken, thans overtrof zy wat alles wat wy ons immer daarvan hadden kunnen voorstellen daar wy langs eene weg zoo hard en zoo even als een kolfbaan rydende aan de linkerzyde hemelhooge bergen hadden met zwaar hout bewassen en aan de rechterhand eene onafzienbare diepte, waarvan wy alleen door een klein hekje waren afgescheiden, zoodat ik met wilde paarden hier niet graag zoude gereden hebben, naast ons vloeide de Rehberger graben : weldra kwamen wy aan de hooge Rehberger klippen welke men ons tevoren als een waarlyk Zwitsersche party had afgeschilderd, ook trof ons zeer het gezicht van deeze hooge Kaale rots welke byna loodregt tusschen de zwaare dennebomen instaat: daarna zagen wy eene schoone waterval juist by den slagboom waarvan wy de sleutel ontvangen hadden: gedurig ging onzen gedienstigen gids van den wagen en sloeg ons met zyne hamer die aan een stok bevestigd hem tevens tot wandelstok diende en die hy\xa0',
#   'labels': [{'span': 'Rehberger graben',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Rehberger klippen',
#     'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[49]\xa0',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[illustratie op linker blad: Der Oderteich]\xa0',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'nooit uit de hand legde, eenige stukjes van de groote graniet, Calcedoon en jaspis steenen waarvan ik eenige heb medegenomen; doch dit ging zeer moeilyk in zyn werk want wanneer hy met onbegrypelyk veel moeite soms een klein stukje had afgeslagen, sprong het dikwyls zoo ver, dat hy, na een tyd lang te vergeefsch gezogt te hebben, weer op nieuw aan het werk moest. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Nevens den zoogenaamden Hanetree  en Koningsberg, die wy rechts zagen liggen, merkten wy een zeer sterk eccho op vooral toen wy aldaar een pistool afschoten hetwelk met eene vreeslyke dreuning tot drie maal toe weerkaatst wierd. ',
#   'labels': [{'span': 'Hanetree',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Koningsberg', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Nog steeds langs dezelfde schoone weg rydende kwamen wy by de tamelyk groote val die het kleine riviertje de Oder , dat een loop van 7 uuren  heeft, hier formeert wy stapten uit de wagen gingen derwaarts en vonden onze moeite rykelyk beloont, kort daarna bereikten wy den Oderteich  zynde eene groote hoeveelheid waters ’t welk aldaar door den Odendam  wordt opgehouden & ook tot de mynen gebruikt. ',
#   'labels': [{'span': 'Oder', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': '7 uuren', 'types': ['E54 Dimension']},
#    {'span': 'Oderteich', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Odendam', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Aan de eene zyde was eene diepte van 60 voeten waarin de grootvader  van onzen voerman met paard en wagen was nedergestort waarvan hy als door een wonder goed was afgekomen zynde de paarden en de wagen verpletterd geworden: ',
#   'labels': [{'span': 'diepte van 60 voeten', 'types': ['E54 Dimension']},
#    {'span': 'de grootvader', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'even voor deeze plaats hadden wy nog een val van het water gezien dat van de bergen vloeide en hetzy door kunst hetzy van natuur dwars over de daar voorby stroomende Rehberger graben viel hetgeen een wonderlyk effect deed. ',
#   'labels': [{'span': 'Rehberger graben',
#     'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Nu hadden wy echter het schoone van de weg op en moesten over een portie steenen al hortende en botsende ryden tot wy ongeveer 3 uur  te Oderbrücke aankwamen: ',
#   'labels': [{'span': '3 uur', 'types': ['E52 Time-Span']},
#    {'span': 'Oderbrücke', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'hier dankten wy onzen voerman  af die dadelyk terug reed , en namen verder te voet de togt naar de Bloksberg aan: ',
#   'labels': [{'span': 'voerman', 'types': ['E21 Person']},
#    {'span': 'terug reed', 'types': ['E86 Leaving']},
#    {'span': 'Bloksberg', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'groot was de verwoesting die de hooge sneeuw de vorige winter hier aan de jonge bomen had aangeregt daar geheele streken ver deeze op eene zekere hoogte geknikt waren. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Tot zeer naby den Brocken genaderd verblydeden wy ons reeds in het vooruitzigt van spoedig de berg zelve te bereiken toen wy op eens van Mayer  [50] hoorden dat wy nog eerst een bosch, dat naar onze gedagte geheel terzyde aflag, door moesten, dan den kleinen Brocken bestygen &, van deeze wederom afdalen moesten en zoo eerst aan het beklimmen der eigenlyke Brocken  konden denken, hoe my en in ’t algemeen ons allen uit de hand viel kunt gy ligtelyk begrypen; ',
#   'labels': [{'span': 'Brocken', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Mayer', 'types': ['E21 Person']},
#    {'span': 'Brocken', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Brocken', 'types': ['E 53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'langsaam namen wy den togt aan, hetgeen men ons ten sterksten had aangeraden wyl het anders byna niet te doen is, reeds hier zagen wy eene plaats eenigsints dieper dan het omliggende gedeelte, waarin voor 5 dagen  nog eene aanmerkelyke hoeveelheid sneeuw geweest was hetgeen men nog wel aan de grond, die geheel gesmart was, zien konde. ',
#   'labels': [{'span': 'voor 5 dagen', 'types': ['time']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'In het zweet onzes aanschyns bereikten wy de top der kleine Brokken , daalden met vry wat minder moeite, evenwel somtyds tot over de enkels door moerassen wadende, gedeeltelyk van dezelve af en begonnen nu den waren Bloksberg te beklimmen. ',
#   'labels': [{'span': 'Brokken', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Bloksberg', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Dat dit met ongelooflyke moeite gepaard ging zult gy ligt begrypen wanneer gy de steilte der berg in aanmerking neemt; schoon zeer vermoeid zynde dorste wy geen oogenblik stilstaan daar wy geheel bezweet waren en eene koude snerpende wind ons dan door merg en beenderen drong. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Zomtyds moesten wy toch tegen wil en dank onzen reisgenoot H. wagten die den Kryg niet kon volgen en die wy toch wagten moesten daar het allergevaarlykst is zich zelfs op eene geringe afstand van zynen gids te verwyderen, onverwagt toch kan men op deeze hoogte door een wolk of dikke nevel omgeven worden ’t geen dodelyke gevolgen zoude kunnen hebben, als men door de overgroote koude bevangen wordt: ',
#   'labels': [{'span': 'H.', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'er zyn veele voorbeelden van reizigers die op deeze wyze van hunne gidsen zyn afgeraakt die geene tien schreden ver konden zien en zich ook niet doen horen daar de dikke nevel de stem geheel verdoofde: gy kunt er een merkwaardig geval van leezen in het 2de deel der brieven over Duitsland op bladz. 70 en volgende. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Gelukkig troffen wy beter weder en kwamen zonder fataliteiten tot boven op de berg alwaar wy byna magteloos',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[51]', 'labels': [], 'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[illustratie op linkerblad: Brockenhauss]',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'op de stoelen in de herberg neder zegen. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Ja myn Vriend op deeze ontzettende hoogte 3480 voet  boven de oppervlakte der Oostzee staat een herberg   waar wy dezen nagt maar eens heerlyk geslapen hebben. ',
#   'labels': [{'span': '3480 voet', 'types': ['E54 Dimension']},
#    {'span': 'herberg', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Dezelve is door den Graaf van Stolberg Heer van Wernigerode in het jaar 1800 tot gemak der reizigers gebouwd: ',
#   'labels': [{'span': 'Graaf van Stolberg Heer van Wernigerode',
#     'types': ['E21 Person']},
#    {'span': 'jaar 1800', 'types': ['E52 Time-Span']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'zy heeft meer dan 19,000 Thaler gekost en bestaat uit 12 kamers  waarvan de muren, om tegen de wind bestand te zyn, vyf voet dik  zyn: ',
#   'labels': [{'span': '12 kamers', 'types': ['E54 Dimension']},
#    {'span': 'vyf voet dik', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'deeze worden twee aan twee door groote kacchels gestookt waarvan wy dadelyk na onze aankomst gebruik maakten daar wy van koude rilden. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Na eenige tyd gerust te hebben gingen wy  wel in onze jassen gewikkelt het een en ander bezien als het Heksen altaar, de Duivels kansel , de Heksen dansplaats , het Wolkenhuisje  hetwelk men ons herhaalde reizen verzekerde dat wel is waar het gansche jaar door tot berging van het een en ander gebruikt, doch den laatsten April  behoorlyk geledigt en gereinigd wierd om in de St Walburgs nagt  alle heksen, die dan op bezemstokken door de lucht rydende gewoon zyn hier te komen, behoorlyk te recipieren. ',
#   'labels': [{'span': 'gingen wy', 'types': ['E9 Move']},
#    {'span': 'Heksen altaar', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Duivels kansel', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Heksen dansplaats', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Wolkenhuisje', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'laatsten April', 'types': ['time']},
#    {'span': 'St Walburgs nagt', 'types': ['time']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'In het zoogenaamde Sneeuw loch  toonde ons Mayer  nog eene groote hoeveelheid sneeuw die er de gansche zomer blyft liggen, zoodat, waren wy er wat digterby geweest, wy ons eens dugtig met sneeuwballen hadden kunnen gooyen. ',
#   'labels': [{'span': 'Sneeuw loch',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Mayer', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'En nu verliet ons Mayer  zeer te vreden met zyn salaris van 2 Thaler hy wilde nog tot de herberg de Oberbrücke terug keeren: veele byzonderheden hadden wy aan dezen man te danken en wy konden ons gerust op hem verlaten daar hy thans voor de 229ste maal den Bloksberg  bestegen had hy scheen het Hartsgebergte  goed te kennen en had het met Profr Hausman , daar hy veel mede op had, vry wat doorkruist. ',
#   'labels': [{'span': 'Mayer', 'types': ['E21 Person']},
#    {'span': 'herberg de Oberbrücke',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Bloksberg', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Hartsgebergte', 'types': ['E53 Place']},
#    {'span': 'Profr Hausman', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Na een allerschrielst souper, bestaande uit een schaapvleesch soep, waarin by ongeluk geloof ik een kaars was kort gekookt, en wat blaauwe besieën , die op de Brocken  groeien en de alsem in bitterheid ver overtreffen, gebruikt te hebben, beklommen wy het observatorium boven op het huis om de zon te zien ondergaan ’t geen ons wegens het benevelde horisont niet mogt gebeuren, en amuseerden ons daarna vry wat met in de menigte albums van reizigers , die hier geweest waren, te bladeren, de meeste hadden eene spreuk of zoo iets by hunne naam, en daar het beklimmen der berg my zeer moeilyk was gevallen',
#   'labels': [{'span': 'schaapvleesch soep', 'types': ['miscellaneous']},
#    {'span': 'blaauwe besieën', 'types': ['miscellaneous']},
#    {'span': 'Brocken', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'observatorium', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'albums van reizigers', 'types': ['miscellaneous']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[52]', 'labels': [], 'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[illustratie op linkerblad: ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Gegend von Wernigerode von den 12 Morgen gesehen]',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'schreef ik per aspera ad astra. ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Voor Zonnen opgang  waren wy alle deze morgen reeds opgestaan om van deeze hoogte dit heerlyke gezicht te genieten, doch het is al weder als gisteren beneveld en behalven de kaale kruin van de berg en eenige naby gelegene voorwerpen ziet men niets, hiervan hebben wy het slegt getroffen, want by helder weder ziet men wel 23 uren gaans verre en dus meer dan 1662 vierkante uren! ',
#   'labels': [{'span': 'Voor Zonnen opgang', 'types': ['time']},
#    {'span': 'gisteren', 'types': ['time']},
#    {'span': '23 uren', 'types': ['E54 Dimension']},
#    {'span': '1662 vierkante uren', 'types': ['E54 Dimension']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Zoo straks zullen wy den berg verlaten, waartoe de waard , die hier uit hoofde der strenge koude slegts gedurende de 3 zomer maanden woont, ons als gids zal dienen tot dat zyn knegt dien hy verwagt, ons ontmoet en verder medegaat; ',
#   'labels': [{'span': 'verlaten', 'types': ['E86 Leaving']},
#    {'span': 'waard', 'types': ['E21 Person']},
#    {'span': '3 zomer maanden woont', 'types': ['time']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'ik zal deeze brief medenemen en dezelve te Elbrugerode  of mooglyk eerder, indien er gelegenheid is, op de post bezorgen. ',
#   'labels': [{'span': 'Elbrugerode', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Van Maagdeburg hoop ik u te schryven en de draad weder van dit oogenblik af optevatten Vaart wel intusschen & denk eens aan uwen Eeuwige Vriend.',
#   'labels': [{'span': 'Maagdeburg', 'types': ['E53 Place']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': '[op linkerblad: ',
#   'labels': [],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'NB. Alleen van de zyde van Wernigerode aan den voet der Brocken  gelegen  van waar de herbergier  gedurig op een muil Ezel zyne provisie krygt, kan deeze berg door zoodanig dier beklommen worden. ',
#   'labels': [{'span': 'Wernigerode', 'types': ['E53 Place']},
#    {'span': 'Brocken', 'types': ['E53 Place', 'E18 Physical Thing']},
#    {'span': 'herbergier', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Langs dat zelfde pad is Jerome Napoleon  tot een ieders verwondering eens met een twaalftal ruiters boven op de Brocken geweest. –\xa0',
#   'labels': [{'span': 'Jerome Napoleon', 'types': ['E21 Person']}],
#   'source': 'Zesde Brief (met annotaties).docx'},
#  {'text': 'Vierde Brief.',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Göttingen den 9 July 1816 .',
#   'labels': [{'span': 'Göttingen', 'types': ['E53 Place']},
#    {'span': '9 July 1816', 'types': ['E52 Time-Span']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Waardste Vriend!',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Wilhelmshöhe, voorheen Weissenstein genoemd en ook reeds een blaauwe maandag Napoleonshöhe geheten, is een lustplaats aan den Keurvorst van Hessen Cassel toebehorende een groot uur van de stad gelegen: ',
#   'labels': [{'span': 'Wilhelmshöhe', 'types': ['E53 Place']},
#    {'span': 'Weissenstein', 'types': ['E53 Place']},
#    {'span': 'Napoleonshöhe', 'types': ['E53 Place']},
#    {'span': 'Keurvorst van Hessen Cassel', 'types': ['E21 Person']},
#    {'span': 'groot uur', 'types': ['E52 Time-Span']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'de landgraven Karel en Frederik de II hebben hetzelve begonnen & het is op eene heerlyke wyze door den thans regeerende Keurvorst Willem de IX voltooid geworden. ',
#   'labels': [{'span': 'Karel', 'types': ['E21 Person']},
#    {'span': 'Frederik de II', 'types': ['E21 Person']},
#    {'span': 'Keurvorst Willem de IX', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Even als ik reeds meermalen gedaan heb zal ik u maar alles in die orde mededeelen als het ons is voorgekomen. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Langs eene lange breede laan gingen wy Zondag ll  naar het zoo beroemde Weissenstein en wel op dien dag omdat alle waterwerken dan in beweging zyn hetgeen men niet dan met groote moeite op andere dagen gedaan kan krygen waarby men dan toch altyd het groote gewoel der wandelaars zoo wel inwoners der stad als vreemdelingen mist. ',
#   'labels': [{'span': 'Zondag ll', 'types': ['E52 Time-Span']},
#    {'span': 'Weissenstein', 'types': ['E53 Place']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Op eenige afstand der stad gekomen zagen wy regts af de enorme Casernes  door Jerome in zyne tyd gebouwd waar verscheiden duizend man, ja volgens het zeggen van iemand, ’t geen my echter onwaarschynlyk voorkomt, wel 30,000 man  in geborgen kunnen worden: deeze linden allee is aan weerszyde met huizen bezet waaronder eenige zeer goede en enkele mooye tuinhuizen; ',
#   'labels': [{'span': 'Casernes', 'types': ['E19 Physical Thing']},
#    {'span': 'Jerome', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'dan spoedig maar uit die laan, verbeeldt u thans maar voor het paleis te staan dat op een zagt glooyend terras is gebouwd aan de eene zyde met de gouden letteren Wilhelmshöhe & aan de andere zyde met de woorden Gulielmus IX Elector condidit, prykt. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Het is in eene bevallige smaak gebouwd met een plat dak voorzien waaruit zich eene koepel verheft van 62 voeten doorsnede en van waar, zoo als wy vervolgens zagen, men een heerlyk gezicht op Cassel en de omliggende streken heeft voor het overige bestaat het geheel uit een hoofdgebouw & twee vleugelen die door een zoort van verdekte galery vereenigd zyn. ',
#   'labels': [{'span': 'een plat dak', 'types': ['E19 Physical Thing']},
#    {'span': '62 voeten', 'types': ['E54 Dimension']},
#    {'span': 'Cassel', 'types': ['E53 Place']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Inwendig beantwoordt alles aan het grootsche denkbeeld dat men by het eerste gezicht reeds heeft opgevat; ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
# ...
#   'labels': [{'span': 'de persoon van de kastelein', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'H.  was dood af, schoon hy zich op\xa0',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': '[48]\xa0',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': '[illustraties op linker blad: Der Rehberger Graben en Der Rehbergergraben am Harz]\xa0',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'zyn lopen te voren vry wat beroemd had. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Daar wy de mynen te Clauthal  de vorige dag  gezien hadden lieten wy de mynen, die hier ook in menigte zyn, onbezogt, verkwikten ons in de herberg zoo goed mogelyk en gingen toen eenen Mayer  opzoeken  om ons als gids by het bestygen der Bloksberg  te dienen; ',
#   'labels': [{'span': 'Mayer', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'deeze man was ons door Profr Hausman  uit Göttingen  aangevolen en naauwlyks had hy zulks gehoord of hy was buiten zich zelven van vreugd en beloofde ons dadelyk gereed te zullen zyn. ',
#   'labels': [{'span': 'Göttingen', 'types': ['E53 Place']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Na een permissie biljet bekomen te hebben om de weg bylangs de Rehberger Graben ,  ’t geen eene particuliere weg scheen te zyn, te mogen ryden vertrokken wy  om 1 uur  met een goede korfwagen  van Andreasberg : ',
#   'labels': [{'span': 'Rehberger Graben', 'types': ['E19 Physical Thing']},
#    {'span': 'vertrokken wy', 'types': ['E86 Leaving']},
#    {'span': 'korfwagen', 'types': ['E19 Physical Thing']},
#    {'span': 'Andreasberg', 'types': ['E53 Place']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Mayer , die met ons op de wagen zat, toonde ons vooreerst de waterleidingen die met ongehoorde moeite en voor de som van 13,000 thalers van boven den eenen berg waren afgeleid en onder eenen anderen doorgevoerd om al het nodige tot de explotatie der mynen in beweging te brengen. ',
#   'labels': [{'span': 'Mayer', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Had ons tot nu toe de weg door de Harz schoon toegeleken, thans overtrof zy wat alles wat wy ons immer daarvan hadden kunnen voorstellen daar wy langs eene weg zoo hard en zoo even als een kolfbaan rydende aan de linkerzyde hemelhooge bergen hadden met zwaar hout bewassen en aan de rechterhand eene onafzienbare diepte, waarvan wy alleen door een klein hekje waren afgescheiden, zoodat ik met wilde paarden hier niet graag zoude gereden hebben, naast ons vloeide de Rehberger graben : weldra kwamen wy aan de hooge Rehberger klippen  welke men ons tevoren als een waarlyk Zwitsersche party had afgeschilderd, ook trof ons zeer het gezicht van deeze hooge Kaale rots welke byna loodregt tusschen de zwaare dennebomen instaat: daarna zagen wy eene schoone waterval juist by den slagboom waarvan wy de sleutel ontvangen hadden: gedurig ging onzen gedienstigen gids van den wagen en sloeg ons met zyne hamer die aan een stok bevestigd hem tevens tot wandelstok diende en die hy\xa0',
#   'labels': [{'span': 'Rehberger graben',
#     'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': '[49]\xa0',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': '[illustratie op linker blad: Der Oderteich]\xa0',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'nooit uit de hand legde, eenige stukjes van de groote graniet, Calcedoon en jaspis steenen waarvan ik eenige heb medegenomen; doch dit ging zeer moeilyk in zyn werk want wanneer hy met onbegrypelyk veel moeite soms een klein stukje had afgeslagen, sprong het dikwyls zoo ver, dat hy, na een tyd lang te vergeefsch gezogt te hebben, weer op nieuw aan het werk moest. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Nevens den zoogenaamden Hanetree  en Koningsberg , die wy rechts zagen liggen, merkten wy een zeer sterk eccho op vooral toen wy aldaar een pistool afschoten hetwelk met eene vreeslyke dreuning tot drie maal toe weerkaatst wierd. ',
#   'labels': [{'span': 'Hanetree',
#     'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Nog steeds langs dezelfde schoone weg rydende kwamen wy by de tamelyk groote val die het kleine riviertje de Oder , dat een loop van 7 uuren  heeft, hier formeert wy stapten uit de wagen gingen derwaarts en vonden onze moeite rykelyk beloont, kort daarna bereikten wy den Oderteich   zynde eene groote hoeveelheid waters ’t welk aldaar door den Odendam  wordt opgehouden & ook tot de mynen gebruikt. ',
#   'labels': [{'span': 'Oder', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Odendam', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Aan de eene zyde was eene diepte van  waarin de grootvader  van onzen voerman met paard en wagen was nedergestort waarvan hy als door een wonder goed was afgekomen zynde de paarden en de wagen verpletterd geworden: ',
#   'labels': [{'span': 'diepte van', 'types': ['E54 Dimension']},
#    {'span': 'de grootvader', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'even voor deeze plaats hadden wy nog een val van het water gezien dat van de bergen vloeide en hetzy door kunst hetzy van natuur dwars over de daar voorby stroomende Rehberger graben  viel hetgeen een wonderlyk effect deed. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Nu hadden wy echter het schoone van de weg op en moesten over een portie steenen al hortende en botsende ryden tot wy ongeveer 3 uur  te Oderbrücke  aankwamen: ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'hier dankten wy onzen voerman  af die dadelyk terug reed , en namen verder te voet de togt naar de Bloksberg  aan: ',
#   'labels': [{'span': 'voerman', 'types': ['E21 Person']},
#    {'span': 'terug reed', 'types': ['E86 Leaving']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'groot was de verwoesting die de hooge sneeuw de vorige winter hier aan de jonge bomen had aangeregt daar geheele streken ver deeze op eene zekere hoogte geknikt waren. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Tot zeer naby den Brocken  genaderd verblydeden wy ons reeds in het vooruitzigt van spoedig de berg zelve te bereiken toen wy op eens van Mayer  [50] hoorden dat wy nog eerst een bosch, dat naar onze gedagte geheel terzyde aflag, door moesten, dan den kleinen Brocken  bestygen &, van deeze wederom afdalen moesten en zoo eerst aan het beklimmen der eigenlyke Brocken  konden denken, hoe my en in ’t algemeen ons allen uit de hand viel kunt gy ligtelyk begrypen; ',
#   'labels': [{'span': 'Mayer', 'types': ['E21 Person']},
#    {'span': 'Brocken', 'types': ['E 53 Place', 'E19 Physical Thing']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'langsaam namen wy den togt aan, hetgeen men ons ten sterksten had aangeraden wyl het anders byna niet te doen is, reeds hier zagen wy eene plaats eenigsints dieper dan het omliggende gedeelte, waarin voor 5 dagen  nog eene aanmerkelyke hoeveelheid sneeuw geweest was hetgeen men nog wel aan de grond, die geheel gesmart was, zien konde. ',
#   'labels': [{'span': 'voor 5 dagen', 'types': ['time']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'In het zweet onzes aanschyns bereikten wy de top der kleine Brokken , daalden met vry wat minder moeite, evenwel somtyds tot over de enkels door moerassen wadende, gedeeltelyk van dezelve af en begonnen nu den waren Bloksberg  te beklimmen. ',
#   'labels': [{'span': 'Brokken',
#     'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Dat dit met ongelooflyke moeite gepaard ging zult gy ligt begrypen wanneer gy de steilte der berg in aanmerking neemt; schoon zeer vermoeid zynde dorste wy geen oogenblik stilstaan daar wy geheel bezweet waren en eene koude snerpende wind ons dan door merg en beenderen drong. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Zomtyds moesten wy toch tegen wil en dank onzen reisgenoot H.  wagten die den Kryg niet kon volgen en die wy toch wagten moesten daar het allergevaarlykst is zich zelfs op eene geringe afstand van zynen gids te verwyderen, onverwagt toch kan men op deeze hoogte door een wolk of dikke nevel omgeven worden ’t geen dodelyke gevolgen zoude kunnen hebben, als men door de overgroote koude bevangen wordt: er zyn veele voorbeelden van reizigers die op deeze wyze van hunne gidsen zyn afgeraakt die geene tien schreden ver konden zien en zich ook niet doen horen daar de dikke nevel de stem geheel verdoofde: gy kunt er een merkwaardig geval van leezen in het 2de deel der brieven over Duitsland op bladz. 70 en volgende. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Gelukkig troffen wy beter weder en kwamen zonder fataliteiten tot boven op de berg alwaar wy byna magteloos',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': '[51]', 'labels': [], 'source': 'Ontology-based Annotation.docx'},
#  {'text': '[illustratie op linkerblad: Brockenhauss]',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'op de stoelen in de herberg neder zegen. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Ja myn Vriend op deeze ontzettende hoogte 3480 voet  boven de oppervlakte der Oostzee staat een herberg  waar wy dezen nagt maar eens heerlyk geslapen hebben. ',
#   'labels': [{'span': '3480 voet', 'types': ['E54 Dimension']},
#    {'span': 'herberg', 'types': ['E53 Place', 'E19 Physical Thing']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Dezelve is door den Graaf van Stolberg Heer van Wernigerode  in het jaar 1800  tot gemak der reizigers gebouwd: ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'zy heeft meer dan 19,000 Thaler gekost en bestaat uit 12 kamers  waarvan de muren, om tegen de wind bestand te zyn, vyf voet dik  zyn: ',
#   'labels': [{'span': '12 kamers', 'types': ['E54 Dimension']},
#    {'span': 'vyf voet dik', 'types': ['E54 Dimension']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'deeze worden twee aan twee door groote kacchels gestookt waarvan wy dadelyk na onze aankomst gebruik maakten daar wy van koude rilden. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Na eenige tyd gerust te hebben gingen wy  wel in onze jassen gewikkelt het een en ander bezien als het Heksen altaar , de Duivels kansel , de Heksen dansplaats , het Wolkenhuisje  hetwelk men ons herhaalde reizen verzekerde dat wel is waar het gansche jaar door tot berging van het een en ander gebruikt, doch den laatsten April  behoorlyk geledigt en gereinigd wierd om in de St Walburgs nagt  alle heksen, die dan op bezemstokken door de lucht rydende gewoon zyn hier te komen, behoorlyk te recipieren. ',
#   'labels': [{'span': 'gingen wy', 'types': ['E9 Move']},
#    {'span': 'Duivels kansel', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Heksen dansplaats', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Wolkenhuisje', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'laatsten April', 'types': ['time']},
#    {'span': 'St Walburgs nagt', 'types': ['time']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'In het zoogenaamde Sneeuw loch  toonde ons Mayer  nog eene groote hoeveelheid sneeuw die er de gansche zomer blyft liggen, zoodat, waren wy er wat digterby geweest, wy ons eens dugtig met sneeuwballen hadden kunnen gooyen. ',
#   'labels': [{'span': 'Sneeuw loch',
#     'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Mayer', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'En nu verliet ons Mayer  zeer te vreden met zyn salaris van 2 Thaler hy wilde nog tot de herberg de Oberbrücke  terug keeren: veele byzonderheden hadden wy aan dezen man te danken en wy konden ons gerust op hem verlaten daar hy thans voor de 229ste maal den Bloksberg  bestegen had hy scheen het Hartsgebergte  goed te kennen en had het met Profr Hausman , daar hy veel mede op had, vry wat doorkruist. ',
#   'labels': [{'span': 'Mayer', 'types': ['E21 Person']},
#    {'span': 'Bloksberg', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'Hartsgebergte', 'types': ['E53 Place']},
#    {'span': 'Profr Hausman', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Na een allerschrielst souper, bestaande uit een schaapvleesch soep , waarin by ongeluk geloof ik een kaars was kort gekookt, en wat blaauwe besieën , die op de Brocken  groeien en de alsem in bitterheid ver overtreffen, gebruikt te hebben, beklommen wy het observatorium  boven op het huis om de zon te zien ondergaan ’t geen ons wegens het benevelde horisont niet mogt gebeuren, en amuseerden ons daarna vry wat met in de menigte albums van reizigers , die hier geweest waren, te bladeren, de meeste hadden eene spreuk of zoo iets by hunne naam, en daar het beklimmen der berg my zeer moeilyk was gevallen',
#   'labels': [{'span': 'blaauwe besieën', 'types': ['miscellaneous']},
#    {'span': 'Brocken', 'types': ['E53 Place', 'E19 Physical Thing']},
#    {'span': 'albums van reizigers', 'types': ['miscellaneous']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': '[52]', 'labels': [], 'source': 'Ontology-based Annotation.docx'},
#  {'text': '[illustratie op linkerblad: ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Gegend von Wernigerode von den 12 Morgen gesehen]',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'schreef ik per aspera ad astra. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Voor Zonnen opgang  waren wy alle deze morgen reeds opgestaan om van deeze hoogte dit heerlyke gezicht te genieten, doch het is al weder als gisteren  beneveld en behalven de kaale kruin van de berg en eenige naby gelegene voorwerpen ziet men niets, hiervan hebben wy het slegt getroffen, want by helder weder ziet men wel 23 uren  gaans verre en dus meer dan 1662 vierkante uren ! ',
#   'labels': [{'span': 'Voor Zonnen opgang', 'types': ['time']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Zoo straks zullen wy den berg verlaten , waartoe de waard , die hier uit hoofde der strenge koude slegts gedurende de 3 zomer maanden woont , ons als gids zal dienen tot dat zyn knegt dien hy verwagt, ons ontmoet en verder medegaat; ',
#   'labels': [{'span': 'waard', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'ik zal deeze brief medenemen en dezelve te Elbrugerode  of mooglyk eerder, indien er gelegenheid is, op de post bezorgen. ',
#   'labels': [{'span': 'Elbrugerode', 'types': ['E53 Place']}],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Van Maagdeburg  hoop ik u te schryven en de draad weder van dit oogenblik af optevatten Vaart wel intusschen & denk eens aan uwen Eeuwige Vriend.',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': '[op linkerblad: ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'NB. Alleen van de zyde van Wernigerode  aan den voet der Brocken  gelegen  van waar de herbergier  gedurig op een muil Ezel zyne provisie krygt, kan deeze berg door zoodanig dier beklommen worden. ',
#   'labels': [],
#   'source': 'Ontology-based Annotation.docx'},
#  {'text': 'Langs dat zelfde pad is Jerome Napoleon  tot een ieders verwondering eens met een twaalftal ruiters boven op de Brocken geweest. –\xa0',
#   'labels': [{'span': 'Jerome Napoleon', 'types': ['E21 Person']}],
#   'source': 'Ontology-based Annotation.docx'}]

# %%
from collections import Counter

counts = Counter(t for ex in all_examples for lab in ex["labels"] for t in lab["types"])
counts.most_common()
# Out:
# [('E53 Place', 204),
#  ('E19 Physical Thing', 115),
#  ('E21 Person', 89),
#  ('E54 Dimension', 40),
#  ('E52 Time-Span', 25),
#  ('time', 16),
#  ('E86 Leaving', 9),
#  ('E74 Group', 8),
#  ('miscellaneous', 8),
#  ('E9 Move', 5),
#  ('mythological figure', 5),
#  ('artwork', 4),
#  ('lecture', 4),
#  ('F2 Expression', 3),
#  ('E 53 Place', 2),
#  ('E21 Persons', 2),
#  ('E18 Physical Thing', 1),
#  ('P183 ends before the start of', 1),
#  ('E31 Document', 1),
#  ('E53', 1),
#  ('Place', 1),
#  ('number of students', 1),
#  ('country', 1),
#  ('categories of books', 1),
#  ('document/lecture', 1),
#  ('discipline/lecture', 1),
#  ('E55 Type', 1),
#  ('distance', 1),
#  ('student culture', 1)]

# %%
# see Jan 30 mail

update_label_map = {
    "E 53 Place": "E53 Place",
    "E21 Persons": "E21 Person",
    "E18 Physical Thing": "E19 Physical Thing",
    "E53": "E53 Place",
    "Place": "E53 Place",
    "time": "E52 Time-Span",
    "mythological figure": "E21 Person",
    "number of students": "E54 Dimension",
    "country": "E53 Place",
    "categories of books": "E55 Type",
    "document/lecture": "E55 Type",
    "discipline/lecture": "E7 Activity",
    "distance": "E54 dimension",
}

# %%
def update_labels(example):
    labels = example["labels"]
    for lab in labels:
        new_types =  [
            update_label_map[t] if t in update_label_map else t for t in lab["types"]
        ]

        new_types = [t for t in new_types if t[0] in ("E", "F", "P")]


        lab["types"] = new_types
        
    example["labels"] = labels
    return example


updated_examples = [update_labels(example) for example in all_examples]
counts = Counter(
    t for ex in updated_examples for lab in ex["labels"] for t in lab["types"]
)

counts
# Out:
# Counter({'E53 Place': 209,
#          'E19 Physical Thing': 116,
#          'E21 Person': 96,
#          'E52 Time-Span': 41,
#          'E54 Dimension': 41,
#          'E86 Leaving': 9,
#          'E74 Group': 8,
#          'E9 Move': 5,
#          'F2 Expression': 3,
#          'E55 Type': 3,
#          'P183 ends before the start of': 1,
#          'E31 Document': 1,
#          'E7 Activity': 1,
#          'E54 dimension': 1})

# %%
from collections import defaultdict

types_per_source = defaultdict(list)

for ex in updated_examples:
    types_per_source[ex["source"]] += [t for lab in ex["labels"] for t in lab["types"]]

for source, types in types_per_source.items():
    print(source)
    print(Counter(types).most_common())
# Out:
# Zesde Brief (met annotaties).docx
# [('E53 Place', 83), ('E19 Physical Thing', 52), ('E21 Person', 29), ('E52 Time-Span', 27), ('E54 Dimension', 22), ('E86 Leaving', 6), ('E74 Group', 4), ('E9 Move', 4)]
# Ontology-based Annotation.docx
# [('E53 Place', 126), ('E21 Person', 67), ('E19 Physical Thing', 64), ('E54 Dimension', 19), ('E52 Time-Span', 14), ('E74 Group', 4), ('F2 Expression', 3), ('E55 Type', 3), ('E86 Leaving', 3), ('P183 ends before the start of', 1), ('E31 Document', 1), ('E7 Activity', 1), ('E54 dimension', 1), ('E9 Move', 1)]

# %%
with datadir.joinpath("examples_cleaned.jsonl").open("w", encoding="utf-8") as f:
    for ex in updated_examples:
        f.write(json.dumps(ex, ensure_ascii=False) + "\n")
